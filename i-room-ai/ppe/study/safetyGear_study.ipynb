# %% [markdown]
# # 환경 설정

# %%
# Google Drive 마운트
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install ultralytics -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 19.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 5.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 99.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 92.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 56.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 11.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 39.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 19.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 93.2 MB/s eta 0:00:00

# %%
# !rm -rf /content/YOLO_safety
print("🧹 YOLO_safety 폴더 완전 삭제 완료")
# Out:
# 🧹 YOLO_safety 폴더 완전 삭제 완료

# %%
# !rm -rf /content/YOLO_safety/val

# %% [markdown]
# # 데이터 압축 해제

# %%
# zip 파일 읽어서 압축 해제

import os
import zipfile

# 경로 설정
base_dir = "/content/YOLO_safety"   # colab 로컬 디렉토리
os.makedirs(base_dir, exist_ok=True)

zip_path = "/content/drive/MyDrive/AI/"

# 압축 해제 함수
def unzip_files(zip_path, target_dir):
    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        zip_ref.extractall(target_dir)
    print(f"압축 해제 완료: {zip_path} -> {target_dir}")

# 압축 해제
file_name = "final.zip"
unzip_files(zip_path + file_name, base_dir)

# # 압축 해제
# file_name = "2_bbox_completed.zip"
# unzip_files(zip_path + file_name, base_dir)
# Out:
# 압축 해제 완료: /content/drive/MyDrive/AI/final.zip -> /content/YOLO_safety

# %% [markdown]
# # JSON 라벨을 YOLO 포맷으로 변환

# %%
import json
from pathlib import Path

def convert_box_json_to_yolo(json_dir, output_dir, class_map, log_path="convert_log.txt"):
    """
    box 또는 polygon 기반 JSON 라벨을 YOLO 포맷으로 변환하는 함수.
    - polygon은 좌표의 min/max로 bounding box 추정
    - bbox 유효성 검사 포함
    - 객체가 없더라도 빈 .txt 파일을 생성하여 학습 누락 방지
    """
    json_dir = Path(json_dir)
    output_dir = Path(output_dir)
    output_dir.mkdir(parents=True, exist_ok=True)
    log_file = Path(log_path)

    json_files = list(json_dir.glob("*.json"))
    log_lines = [f"총 {len(json_files)}개의 JSON 파일을 처리합니다.\n\n"]

    converted_count = 0
    skipped_empty = 0
    skipped_class = 0
    skipped_invalid_bbox = 0

    for json_file in json_files:
        with open(json_file, "r", encoding="utf-8") as f:
            data = json.load(f)

        filename = data["image"]["filename"]
        img_width, img_height = data["image"]["resolution"]
        label_lines = []

        for ann in data.get("annotations", []):
            class_id_raw = ann.get("class")
            if class_id_raw not in class_map:
                skipped_class += 1
                continue

            class_id = class_map[class_id_raw]

            # box 우선 사용
            box = ann.get("box")
            if box and len(box) == 4:
                xmin, ymin, xmax, ymax = box
            elif "polygon" in ann and len(ann["polygon"]) >= 3:
                xs = [pt[0] for pt in ann["polygon"]]
                ys = [pt[1] for pt in ann["polygon"]]
                xmin, xmax = min(xs), max(xs)
                ymin, ymax = min(ys), max(ys)
            else:
                continue

            if (xmax - xmin < 1) or (ymax - ymin < 1):
                skipped_invalid_bbox += 1
                continue
            if not (0 <= xmin < xmax <= img_width) or not (0 <= ymin < ymax <= img_height):
                skipped_invalid_bbox += 1
                continue

            # YOLO format 변환
            cx = ((xmin + xmax) / 2) / img_width
            cy = ((ymin + ymax) / 2) / img_height
            w = (xmax - xmin) / img_width
            h = (ymax - ymin) / img_height

            label_lines.append(f"{class_id} {cx:.6f} {cy:.6f} {w:.6f} {h:.6f}")

        label_file = output_dir / (Path(filename).stem + ".txt")
        with open(label_file, "w") as out_f:
            if label_lines:
                out_f.write("\n".join(label_lines))
                converted_count += 1
                log_lines.append(f"✅ 변환 완료: {filename} → {len(label_lines)}개 객체\n")
            else:
                out_f.write("")  # 객체 없더라도 빈 파일 생성
                skipped_empty += 1
                log_lines.append(f"⚠️ 객체 없음 (빈 라벨 생성): {filename}\n")

    # 최종 요약
    log_lines.append("\n📌 변환 요약 📌\n")
    log_lines.append(f"✅ 변환된 라벨 수: {converted_count}개\n")
    log_lines.append(f"⚠️ 빈 라벨 (객체 없음): {skipped_empty}개\n")
    log_lines.append(f"🚫 class_map 미등록 클래스: {skipped_class}개\n")
    log_lines.append(f"🚫 잘못된 bbox (너무 작거나 범위 초과): {skipped_invalid_bbox}개\n")

    # 로그 파일 저장 (마지막에 한 번만 엶)
    with log_file.open("w", encoding="utf-8") as log:
        log.writelines(log_lines)

    # 이미지 디렉토리 존재 확인
    print("✅ train images exists:", Path("/content/YOLO_safety/train/images").exists())
    print("✅ val images exists:", Path("/content/YOLO_safety/val/images").exists())

    # 라벨 디렉토리 + 파일 개수 확인
    train_labels = list(Path("/content/YOLO_safety/train/labels").glob("*.txt"))
    print(f"✅ train 라벨 수: {len(train_labels)}개")

    val_labels = list(Path("/content/YOLO_safety/val/labels").glob("*.txt"))
    print(f"✅ val 라벨 수: {len(val_labels)}개")

    # 비어있는 파일 확인
    empty = [f for f in val_labels if f.stat().st_size == 0]
    print(f"⚠️ 비어있는 라벨 파일 수: {len(empty)}개")

    print(f"🔍 라벨 변환 로그가 '{log_path}'에 저장되었습니다.")

# %%
# 클래스 매핑: JSON 클래스 번호(str) → YOLO 클래스 인덱스(int)
class_mapping_all = {
    "01": 0,  # 안전벨트 착용
    "07": 1,  # 안전모 착용
}

# ✅ 학습 데이터 전체 변환 (01, 07 모두 포함된 json 폴더 기준)
convert_box_json_to_yolo(
    json_dir="/content/YOLO_safety/train/labels_json",  # 통합 디렉토리
    output_dir="/content/YOLO_safety/train/labels",
    class_map=class_mapping_all,
    log_path="train_log.txt"
)
print("✅ 학습 데이터 전체 라벨 변환 완료")

# ✅ 검증 데이터 전체 변환
convert_box_json_to_yolo(
    json_dir="/content/YOLO_safety/val/labels_json",  # 통합 디렉토리
    output_dir="/content/YOLO_safety/val/labels",
    class_map=class_mapping_all,
    log_path="val_log.txt"
)
print("✅ 검증 데이터 전체 라벨 변환 완료")
# Out:
# ✅ train images exists: True
# ✅ val images exists: True
# ✅ train 라벨 수: 44554개
# ✅ val 라벨 수: 0개
# ⚠️ 비어있는 라벨 파일 수: 0개
# 🔍 라벨 변환 로그가 'train_log.txt'에 저장되었습니다.
# ✅ 학습 데이터 전체 라벨 변환 완료
# ✅ train images exists: True
# ✅ val images exists: True
# ✅ train 라벨 수: 44554개
# ✅ val 라벨 수: 10820개
# ⚠️ 비어있는 라벨 파일 수: 0개
# 🔍 라벨 변환 로그가 'val_log.txt'에 저장되었습니다.
# ✅ 검증 데이터 전체 라벨 변환 완료

# %%
from pathlib import Path
import os

labels_dir = Path("/content/YOLO_safety/train/labels")  # 라벨 폴더 경로 수정

for txt_file in labels_dir.glob("*.txt"):
    new_name = txt_file.with_name(txt_file.stem.lower() + ".txt")
    os.rename(txt_file, new_name)
    print(f"Renamed: {txt_file.name} → {new_name.name}")
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# Renamed: S2-N1106M10286.txt → s2-n1106m10286.txt
# Renamed: S2-N1206M02248.txt → s2-n1206m02248.txt
# Renamed: S2-N1105M01945.txt → s2-n1105m01945.txt
# Renamed: S2-N1106M10030.txt → s2-n1106m10030.txt
# Renamed: S2-N1106M24697.txt → s2-n1106m24697.txt
# Renamed: S2-N1106M05679.txt → s2-n1106m05679.txt
# Renamed: S2-N1106M02600.txt → s2-n1106m02600.txt
# Renamed: S2-N1001M01557.txt → s2-n1001m01557.txt
# Renamed: S2-N1106M22564.txt → s2-n1106m22564.txt
# Renamed: S2-N1106M18912.txt → s2-n1106m18912.txt
# Renamed: S2-N1106M16778.txt → s2-n1106m16778.txt
# Renamed: S2-N1206M00785.txt → s2-n1206m00785.txt
# Renamed: S2-N1106M21056.txt → s2-n1106m21056.txt
# Renamed: S2-N1402M03340.txt → s2-n1402m03340.txt
# Renamed: S2-N1001M01363.txt → s2-n1001m01363.txt
# Renamed: S2-N1106M08485.txt → s2-n1106m08485.txt
# Renamed: S2-N1106M03883.txt → s2-n1106m03883.txt
# Renamed: S2-N1106M05399.txt → s2-n1106m05399.txt
# Renamed: S2-N1106M14397.txt → s2-n1106m14397.txt
# Renamed: S2-O1301M00083.txt → s2-o1301m00083.txt
# Renamed: S2-N0109M35913.txt → s2-n0109m35913.txt
# Renamed: S2-N1105M23657.txt → s2-n1105m23657.txt
# Renamed: S2-N1001M01201.txt → s2-n1001m01201.txt
# Renamed: S2-N1106M04927.txt → s2-n1106m04927.txt
# Renamed: S2-N0109M07926.txt → s2-n0109m07926.txt
# Renamed: S2-N1105M03144.txt → s2-n1105m03144.txt
# Renamed: S2-N1105M12343.txt → s2-n1105m12343.txt
# Renamed: S2-N1106M00487.txt → s2-n1106m00487.txt
# Renamed: S2-N1106M18266.txt → s2-n1106m18266.txt
# Renamed: S2-N1105M22742.txt → s2-n1105m22742.txt
# Renamed: S2-N0109M18032.txt → s2-n0109m18032.txt
# Renamed: S2-N1106M26368.txt → s2-n1106m26368.txt
# Renamed: S2-O1102M00427.txt → s2-o1102m00427.txt
# Renamed: S2-N0109M46424.txt → s2-n0109m46424.txt
# Renamed: S2-N1106M03410.txt → s2-n1106m03410.txt
# Renamed: S2-N1105M00960.txt → s2-n1105m00960.txt
# Renamed: S2-N2104M20555.txt → s2-n2104m20555.txt
# Renamed: S2-N1106M04771.txt → s2-n1106m04771.txt
# Renamed: S2-N1106M26023.txt → s2-n1106m26023.txt
# Renamed: S2-O1103M03357.txt → s2-o1103m03357.txt
# Renamed: S2-N1105M01504.txt → s2-n1105m01504.txt
# Renamed: S2-N0110M08708.txt → s2-n0110m08708.txt
# Renamed: S2-N1106M21211.txt → s2-n1106m21211.txt
# Renamed: S2-N1106M09263.txt → s2-n1106m09263.txt
# Renamed: S2-N1106M22681.txt → s2-n1106m22681.txt
# Renamed: S2-N1106M18288.txt → s2-n1106m18288.txt
# Renamed: S2-N0109M14077.txt → s2-n0109m14077.txt
# Renamed: S2-N1106M05851.txt → s2-n1106m05851.txt
# Renamed: S2-O1301M01897.txt → s2-o1301m01897.txt
# Renamed: S2-O1103M03880.txt → s2-o1103m03880.txt
# Renamed: S2-N1402M08695.txt → s2-n1402m08695.txt
# Renamed: S2-N1105M00194.txt → s2-n1105m00194.txt
# Renamed: S2-N0109M36470.txt → s2-n0109m36470.txt
# Renamed: S2-N1105M25869.txt → s2-n1105m25869.txt
# Renamed: S2-N1106M12978.txt → s2-n1106m12978.txt
# Renamed: S2-O1301M00581.txt → s2-o1301m00581.txt
# Renamed: S2-N1106M11808.txt → s2-n1106m11808.txt
# Renamed: S2-N1106M04680.txt → s2-n1106m04680.txt
# Renamed: S2-N1106M19775.txt → s2-n1106m19775.txt
# Renamed: S2-N1106M19442.txt → s2-n1106m19442.txt
# Renamed: S2-N1106M11951.txt → s2-n1106m11951.txt
# Renamed: S2-N1105M12324.txt → s2-n1105m12324.txt
# Renamed: S2-N2104M19065.txt → s2-n2104m19065.txt
# Renamed: S2-N0110M00954.txt → s2-n0110m00954.txt
# Renamed: S2-N1106M10296.txt → s2-n1106m10296.txt
# Renamed: S2-N1106M12610.txt → s2-n1106m12610.txt
# Renamed: S2-N1106M03771.txt → s2-n1106m03771.txt
# Renamed: S2-N1105M13360.txt → s2-n1105m13360.txt
# Renamed: S2-N1105M01570.txt → s2-n1105m01570.txt
# Renamed: S2-N1105M06614.txt → s2-n1105m06614.txt
# Renamed: S2-N1106M00465.txt → s2-n1106m00465.txt
# Renamed: S2-N1106M02084.txt → s2-n1106m02084.txt
# Renamed: S2-O1301M00696.txt → s2-o1301m00696.txt
# Renamed: S2-N1105M01022.txt → s2-n1105m01022.txt
# Renamed: S2-N1105M01794.txt → s2-n1105m01794.txt
# Renamed: S2-N0109M37909.txt → s2-n0109m37909.txt
# Renamed: S2-N0109M50829.txt → s2-n0109m50829.txt
# Renamed: S2-N1105M18611.txt → s2-n1105m18611.txt
# Renamed: S2-N1105M05615.txt → s2-n1105m05615.txt
# Renamed: S2-N1106M12592.txt → s2-n1106m12592.txt
# Renamed: S2-N1106M27755.txt → s2-n1106m27755.txt
# Renamed: S2-N1105M01230.txt → s2-n1105m01230.txt
# Renamed: S2-N1106M08563.txt → s2-n1106m08563.txt
# Renamed: S2-N2104M19704.txt → s2-n2104m19704.txt
# Renamed: S2-N1104M01443.txt → s2-n1104m01443.txt
# Renamed: S2-N1106M18525.txt → s2-n1106m18525.txt
# Renamed: S2-N1106M02419.txt → s2-n1106m02419.txt
# Renamed: S2-N1105M05606.txt → s2-n1105m05606.txt
# Renamed: S2-N1105M20682.txt → s2-n1105m20682.txt
# Renamed: S2-N1402M07446.txt → s2-n1402m07446.txt
# Renamed: S2-N1106M25163.txt → s2-n1106m25163.txt
# Renamed: S2-N1105M06109.txt → s2-n1105m06109.txt
# Renamed: S2-N1106M15321.txt → s2-n1106m15321.txt
# Renamed: S2-N1106M12127.txt → s2-n1106m12127.txt
# Renamed: S2-N1106M08716.txt → s2-n1106m08716.txt
# Renamed: S2-N1104M01736.txt → s2-n1104m01736.txt
# Renamed: S2-N2103M01472.txt → s2-n2103m01472.txt
# Renamed: S2-N1105M12319.txt → s2-n1105m12319.txt
# Renamed: S2-N1105M00162.txt → s2-n1105m00162.txt
# Renamed: S2-N1106M01792.txt → s2-n1106m01792.txt
# Renamed: S2-N1105M06960.txt → s2-n1105m06960.txt
# Renamed: S2-N1106M01254.txt → s2-n1106m01254.txt
# Renamed: S2-N1105M05775.txt → s2-n1105m05775.txt
# Renamed: S2-N1105M03820.txt → s2-n1105m03820.txt
# Renamed: S2-N1105M13092.txt → s2-n1105m13092.txt
# Renamed: S2-N1106M08745.txt → s2-n1106m08745.txt
# Renamed: S2-N2104M12850.txt → s2-n2104m12850.txt
# Renamed: S2-N1206M04391.txt → s2-n1206m04391.txt
# Renamed: S2-N1106M16260.txt → s2-n1106m16260.txt
# Renamed: S2-N1106M20458.txt → s2-n1106m20458.txt
# Renamed: S2-N0109M40064.txt → s2-n0109m40064.txt
# Renamed: S2-N0108M28345.txt → s2-n0108m28345.txt
# Renamed: S2-N1001M02520.txt → s2-n1001m02520.txt
# Renamed: S2-N1105M07428.txt → s2-n1105m07428.txt
# Renamed: S2-N0109M36069.txt → s2-n0109m36069.txt
# Renamed: S2-N1106M11588.txt → s2-n1106m11588.txt
# Renamed: S2-N1105M01477.txt → s2-n1105m01477.txt
# Renamed: S2-N1106M06995.txt → s2-n1106m06995.txt
# Renamed: S2-N0108M22255.txt → s2-n0108m22255.txt
# Renamed: S2-N0109M11656.txt → s2-n0109m11656.txt
# Renamed: S2-N1402M11524.txt → s2-n1402m11524.txt
# Renamed: S2-N1105M04931.txt → s2-n1105m04931.txt
# Renamed: S2-N1106M17152.txt → s2-n1106m17152.txt
# Renamed: S2-N2104M19777.txt → s2-n2104m19777.txt
# Renamed: S2-N0109M38146.txt → s2-n0109m38146.txt
# Renamed: S2-N1105M13538.txt → s2-n1105m13538.txt
# Renamed: S2-N0109M10079.txt → s2-n0109m10079.txt
# Renamed: S2-N0109M36539.txt → s2-n0109m36539.txt
# Renamed: S2-N1106M05770.txt → s2-n1106m05770.txt
# Renamed: S2-N1106M00302.txt → s2-n1106m00302.txt
# Renamed: S2-N1001M05229.txt → s2-n1001m05229.txt
# Renamed: S2-N0109M43494.txt → s2-n0109m43494.txt
# Renamed: S2-N1206M00016.txt → s2-n1206m00016.txt
# Renamed: S2-N1106M20746.txt → s2-n1106m20746.txt
# Renamed: S2-N0110M04308.txt → s2-n0110m04308.txt
# Renamed: S2-N1105M01638.txt → s2-n1105m01638.txt
# Renamed: S2-N1105M04908.txt → s2-n1105m04908.txt
# Renamed: S2-N1001M01368.txt → s2-n1001m01368.txt
# Renamed: S2-O1103M04574.txt → s2-o1103m04574.txt
# Renamed: S2-N1106M11932.txt → s2-n1106m11932.txt
# Renamed: S2-N1106M17540.txt → s2-n1106m17540.txt
# Renamed: S2-N1106M29077.txt → s2-n1106m29077.txt
# Renamed: S2-N2103M40360.txt → s2-n2103m40360.txt
# Renamed: S2-N1104M00258.txt → s2-n1104m00258.txt
# Renamed: S2-N1106M19806.txt → s2-n1106m19806.txt
# Renamed: S2-N1402M01170.txt → s2-n1402m01170.txt
# Renamed: S2-N1105M11187.txt → s2-n1105m11187.txt
# Renamed: S2-N1105M02015.txt → s2-n1105m02015.txt
# Renamed: S2-N0109M11230.txt → s2-n0109m11230.txt
# Renamed: S2-N1106M02612.txt → s2-n1106m02612.txt
# Renamed: S2-N2102M33023.txt → s2-n2102m33023.txt
# Renamed: S2-N1105M09507.txt → s2-n1105m09507.txt
# Renamed: S2-N1105M09242.txt → s2-n1105m09242.txt
# Renamed: S2-N1105M02225.txt → s2-n1105m02225.txt
# Renamed: S2-N1106M18250.txt → s2-n1106m18250.txt
# Renamed: S2-N1106M09120.txt → s2-n1106m09120.txt
# Renamed: S2-N1106M00577.txt → s2-n1106m00577.txt
# Renamed: S2-N0110M00715.txt → s2-n0110m00715.txt
# Renamed: S2-N1106M12198.txt → s2-n1106m12198.txt
# Renamed: S2-N1105M04466.txt → s2-n1105m04466.txt
# Renamed: S2-N1106M17038.txt → s2-n1106m17038.txt
# Renamed: S2-N1105M18148.txt → s2-n1105m18148.txt
# Renamed: S2-N1105M01286.txt → s2-n1105m01286.txt
# Renamed: S2-N1206M02300.txt → s2-n1206m02300.txt
# Renamed: S2-N1106M21274.txt → s2-n1106m21274.txt
# Renamed: S2-N1105M05071.txt → s2-n1105m05071.txt
# Renamed: S2-O1301M03464.txt → s2-o1301m03464.txt
# Renamed: S2-N1106M05774.txt → s2-n1106m05774.txt
# Renamed: S2-N1105M05138.txt → s2-n1105m05138.txt
# Renamed: S2-O1301M01431.txt → s2-o1301m01431.txt
# Renamed: S2-N0108M29056.txt → s2-n0108m29056.txt
# Renamed: S2-N1206M24120.txt → s2-n1206m24120.txt
# Renamed: S2-N1106M10787.txt → s2-n1106m10787.txt
# Renamed: S2-N1001M00546.txt → s2-n1001m00546.txt
# Renamed: S2-N1106M01450.txt → s2-n1106m01450.txt
# Renamed: S2-N2104M24377.txt → s2-n2104m24377.txt
# Renamed: S2-N1106M05573.txt → s2-n1106m05573.txt
# Renamed: S2-O1301M01956.txt → s2-o1301m01956.txt
# Renamed: S2-N1106M12805.txt → s2-n1106m12805.txt
# Renamed: S2-N1106M06516.txt → s2-n1106m06516.txt
# Renamed: S2-O1301M00349.txt → s2-o1301m00349.txt
# Renamed: S2-N1106M02354.txt → s2-n1106m02354.txt
# Renamed: S2-N1106M11359.txt → s2-n1106m11359.txt
# Renamed: S2-N1105M21795.txt → s2-n1105m21795.txt
# Renamed: S2-N1106M00649.txt → s2-n1106m00649.txt
# Renamed: S2-N1106M08009.txt → s2-n1106m08009.txt
# Renamed: S2-N1105M05780.txt → s2-n1105m05780.txt
# Renamed: S2-N1106M23526.txt → s2-n1106m23526.txt
# Renamed: S2-N1105M05226.txt → s2-n1105m05226.txt
# Renamed: S2-N1106M20726.txt → s2-n1106m20726.txt
# Renamed: S2-N1106M16468.txt → s2-n1106m16468.txt
# Renamed: S2-N1105M01962.txt → s2-n1105m01962.txt
# Renamed: S2-N1105M05458.txt → s2-n1105m05458.txt
# Renamed: S2-N1106M08468.txt → s2-n1106m08468.txt
# Renamed: S2-N1106M02006.txt → s2-n1106m02006.txt
# Renamed: S2-N0109M01414.txt → s2-n0109m01414.txt
# Renamed: S2-N1106M12347.txt → s2-n1106m12347.txt
# Renamed: S2-N1106M25660.txt → s2-n1106m25660.txt
# Renamed: S2-N1105M20755.txt → s2-n1105m20755.txt
# Renamed: S2-N1206M02426.txt → s2-n1206m02426.txt
# Renamed: S2-N1106M04403.txt → s2-n1106m04403.txt
# Renamed: S2-N1402M09722.txt → s2-n1402m09722.txt
# Renamed: S2-N1106M08791.txt → s2-n1106m08791.txt
# Renamed: S2-N1106M13800.txt → s2-n1106m13800.txt
# Renamed: S2-N0108M21008.txt → s2-n0108m21008.txt
# Renamed: S2-N2102M08630.txt → s2-n2102m08630.txt
# Renamed: S2-N1105M13139.txt → s2-n1105m13139.txt
# Renamed: S2-N1105M05699.txt → s2-n1105m05699.txt
# Renamed: S2-N1402M00741.txt → s2-n1402m00741.txt
# Renamed: S2-N1106M09821.txt → s2-n1106m09821.txt
# Renamed: S2-N1106M17166.txt → s2-n1106m17166.txt
# Renamed: S2-N1401M01883.txt → s2-n1401m01883.txt
# Renamed: S2-N1105M03512.txt → s2-n1105m03512.txt
# Renamed: S2-N1106M20585.txt → s2-n1106m20585.txt
# Renamed: S2-N0108M18771.txt → s2-n0108m18771.txt
# Renamed: S2-O1301M00054.txt → s2-o1301m00054.txt
# Renamed: S2-O1301M00438.txt → s2-o1301m00438.txt
# Renamed: S2-N1105M05445.txt → s2-n1105m05445.txt
# Renamed: S2-N0108M18959.txt → s2-n0108m18959.txt
# Renamed: S2-N1106M21231.txt → s2-n1106m21231.txt
# Renamed: S2-N1105M05858.txt → s2-n1105m05858.txt
# Renamed: S2-N1106M04915.txt → s2-n1106m04915.txt
# Renamed: S2-N2104M21741.txt → s2-n2104m21741.txt
# Renamed: S2-N1106M09447.txt → s2-n1106m09447.txt
# Renamed: S2-N1106M20605.txt → s2-n1106m20605.txt
# Renamed: S2-O1301M04121.txt → s2-o1301m04121.txt
# Renamed: S2-N1106M10062.txt → s2-n1106m10062.txt
# Renamed: S2-N1106M15724.txt → s2-n1106m15724.txt
# Renamed: S2-N1106M06603.txt → s2-n1106m06603.txt
# Renamed: S2-N1106M08849.txt → s2-n1106m08849.txt
# Renamed: S2-N0109M46390.txt → s2-n0109m46390.txt
# Renamed: S2-N1106M07382.txt → s2-n1106m07382.txt
# Renamed: S2-N1104M02469.txt → s2-n1104m02469.txt
# Renamed: S2-N0109M41489.txt → s2-n0109m41489.txt
# Renamed: S2-N1105M24929.txt → s2-n1105m24929.txt
# Renamed: S2-N1106M07669.txt → s2-n1106m07669.txt
# Renamed: S2-N1106M19952.txt → s2-n1106m19952.txt
# Renamed: S2-N1401M00250.txt → s2-n1401m00250.txt
# Renamed: S2-N1402M00758.txt → s2-n1402m00758.txt
# Renamed: S2-N0108M21999.txt → s2-n0108m21999.txt
# Renamed: S2-N0110M03404.txt → s2-n0110m03404.txt
# Renamed: S2-N1106M22312.txt → s2-n1106m22312.txt
# Renamed: S2-N1106M10596.txt → s2-n1106m10596.txt
# Renamed: S2-N1106M20525.txt → s2-n1106m20525.txt
# Renamed: S2-N0109M36529.txt → s2-n0109m36529.txt
# Renamed: S2-N1106M22123.txt → s2-n1106m22123.txt
# Renamed: S2-N1106M12935.txt → s2-n1106m12935.txt
# Renamed: S2-N1105M08196.txt → s2-n1105m08196.txt
# Renamed: S2-N1106M23183.txt → s2-n1106m23183.txt
# Renamed: S2-N1106M18754.txt → s2-n1106m18754.txt
# Renamed: S2-N1106M13055.txt → s2-n1106m13055.txt
# Renamed: S2-N1105M20648.txt → s2-n1105m20648.txt
# Renamed: S2-N1402M10530.txt → s2-n1402m10530.txt
# Renamed: S2-N1106M19382.txt → s2-n1106m19382.txt
# Renamed: S2-N1105M26821.txt → s2-n1105m26821.txt
# Renamed: S2-N0109M40470.txt → s2-n0109m40470.txt
# Renamed: S2-N1106M07519.txt → s2-n1106m07519.txt
# Renamed: S2-N1105M06703.txt → s2-n1105m06703.txt
# Renamed: S2-N2104M12897.txt → s2-n2104m12897.txt
# Renamed: S2-N0108M21894.txt → s2-n0108m21894.txt
# Renamed: S2-N1105M01047.txt → s2-n1105m01047.txt
# Renamed: S2-N1106M22843.txt → s2-n1106m22843.txt
# Renamed: S2-N1106M23380.txt → s2-n1106m23380.txt
# Renamed: S2-N1106M04780.txt → s2-n1106m04780.txt
# Renamed: S2-O1301M01751.txt → s2-o1301m01751.txt
# Renamed: S2-N1105M24465.txt → s2-n1105m24465.txt
# Renamed: S2-N2104M26214.txt → s2-n2104m26214.txt
# Renamed: S2-N1105M09941.txt → s2-n1105m09941.txt
# Renamed: S2-N0109M40884.txt → s2-n0109m40884.txt
# Renamed: S2-N1106M01830.txt → s2-n1106m01830.txt
# Renamed: S2-N1105M20883.txt → s2-n1105m20883.txt
# Renamed: S2-N1105M03555.txt → s2-n1105m03555.txt
# Renamed: S2-N1206M11904.txt → s2-n1206m11904.txt
# Renamed: S2-N1106M12105.txt → s2-n1106m12105.txt
# Renamed: S2-N1106M12567.txt → s2-n1106m12567.txt
# Renamed: S2-N1206M06654.txt → s2-n1206m06654.txt
# Renamed: S2-N1105M23125.txt → s2-n1105m23125.txt
# Renamed: S2-N0108M21966.txt → s2-n0108m21966.txt
# Renamed: S2-N1402M11842.txt → s2-n1402m11842.txt
# Renamed: S2-N1105M01270.txt → s2-n1105m01270.txt
# Renamed: S2-N0110M06093.txt → s2-n0110m06093.txt
# Renamed: S2-N1105M11297.txt → s2-n1105m11297.txt
# Renamed: S2-O1301M03543.txt → s2-o1301m03543.txt
# Renamed: S2-N1106M10904.txt → s2-n1106m10904.txt
# Renamed: S2-N1105M10853.txt → s2-n1105m10853.txt
# Renamed: S2-N2104M13177.txt → s2-n2104m13177.txt
# Renamed: S2-N1106M07580.txt → s2-n1106m07580.txt
# Renamed: S2-N1105M08712.txt → s2-n1105m08712.txt
# Renamed: S2-N2104M26440.txt → s2-n2104m26440.txt
# Renamed: S2-N1105M18184.txt → s2-n1105m18184.txt
# Renamed: S2-N1206M05439.txt → s2-n1206m05439.txt
# Renamed: S2-N1106M11243.txt → s2-n1106m11243.txt
# Renamed: S2-N1106M12412.txt → s2-n1106m12412.txt
# Renamed: S2-N0108M01907.txt → s2-n0108m01907.txt
# Renamed: S2-N1106M05855.txt → s2-n1106m05855.txt
# Renamed: S2-N1106M10984.txt → s2-n1106m10984.txt
# Renamed: S2-O1301M04391.txt → s2-o1301m04391.txt
# Renamed: S2-N1105M01304.txt → s2-n1105m01304.txt
# Renamed: S2-N1106M02651.txt → s2-n1106m02651.txt
# Renamed: S2-O1301M01885.txt → s2-o1301m01885.txt
# Renamed: S2-N1106M20197.txt → s2-n1106m20197.txt
# Renamed: S2-O1101M07847.txt → s2-o1101m07847.txt
# Renamed: S2-O1302M00551.txt → s2-o1302m00551.txt
# Renamed: S2-N1206M04925.txt → s2-n1206m04925.txt
# Renamed: S2-O1302M00466.txt → s2-o1302m00466.txt
# Renamed: S2-O1101M04783.txt → s2-o1101m04783.txt
# Renamed: S2-N1402M04018.txt → s2-n1402m04018.txt
# Renamed: S2-N1105M17691.txt → s2-n1105m17691.txt
# Renamed: S2-N1106M04269.txt → s2-n1106m04269.txt
# Renamed: S2-N1106M00348.txt → s2-n1106m00348.txt
# Renamed: S2-N1106M18737.txt → s2-n1106m18737.txt
# Renamed: S2-N1106M12026.txt → s2-n1106m12026.txt
# Renamed: S2-O1103M03821.txt → s2-o1103m03821.txt
# Renamed: S2-O1301M00004.txt → s2-o1301m00004.txt
# Renamed: S2-N1105M04844.txt → s2-n1105m04844.txt
# Renamed: S2-N0109M52551.txt → s2-n0109m52551.txt
# Renamed: S2-N1106M02864.txt → s2-n1106m02864.txt
# Renamed: S2-N1106M23441.txt → s2-n1106m23441.txt
# Renamed: S2-N1106M03357.txt → s2-n1106m03357.txt
# Renamed: S2-N1106M23498.txt → s2-n1106m23498.txt
# Renamed: S2-N1402M10721.txt → s2-n1402m10721.txt
# Renamed: S2-N0110M08092.txt → s2-n0110m08092.txt
# Renamed: S2-N1106M25898.txt → s2-n1106m25898.txt
# Renamed: S2-N1105M04438.txt → s2-n1105m04438.txt
# Renamed: S2-N1106M13689.txt → s2-n1106m13689.txt
# Renamed: S2-N1105M17991.txt → s2-n1105m17991.txt
# Renamed: S2-N1106M15434.txt → s2-n1106m15434.txt
# Renamed: S2-N1001M02020.txt → s2-n1001m02020.txt
# Renamed: S2-N1001M01780.txt → s2-n1001m01780.txt
# Renamed: S2-N1106M03553.txt → s2-n1106m03553.txt
# Renamed: S2-N1105M22857.txt → s2-n1105m22857.txt
# Renamed: S2-N1106M15129.txt → s2-n1106m15129.txt
# Renamed: S2-N1106M21475.txt → s2-n1106m21475.txt
# Renamed: S2-N1106M15674.txt → s2-n1106m15674.txt
# Renamed: S2-N0109M39137.txt → s2-n0109m39137.txt
# Renamed: S2-N1106M01343.txt → s2-n1106m01343.txt
# Renamed: S2-N1106M02975.txt → s2-n1106m02975.txt
# Renamed: S2-N1106M14957.txt → s2-n1106m14957.txt
# Renamed: S2-N1401M01518.txt → s2-n1401m01518.txt
# Renamed: S2-N1106M12753.txt → s2-n1106m12753.txt
# Renamed: S2-N1105M27851.txt → s2-n1105m27851.txt
# Renamed: S2-O1301M04229.txt → s2-o1301m04229.txt
# Renamed: S2-N1106M17904.txt → s2-n1106m17904.txt
# Renamed: S2-N1106M22639.txt → s2-n1106m22639.txt
# Renamed: S2-N1106M02839.txt → s2-n1106m02839.txt
# Renamed: S2-N1206M04485.txt → s2-n1206m04485.txt
# Renamed: S2-N1104M01786.txt → s2-n1104m01786.txt
# Renamed: S2-N1106M00286.txt → s2-n1106m00286.txt
# Renamed: S2-N1106M17488.txt → s2-n1106m17488.txt
# Renamed: S2-N1106M17918.txt → s2-n1106m17918.txt
# Renamed: S2-N1402M09513.txt → s2-n1402m09513.txt
# Renamed: S2-N1105M02591.txt → s2-n1105m02591.txt
# Renamed: S2-N1106M10960.txt → s2-n1106m10960.txt
# Renamed: S2-N1106M22505.txt → s2-n1106m22505.txt
# Renamed: S2-O1301M01997.txt → s2-o1301m01997.txt
# Renamed: S2-N1106M29730.txt → s2-n1106m29730.txt
# Renamed: S2-N1106M14819.txt → s2-n1106m14819.txt
# Renamed: S2-N1106M19085.txt → s2-n1106m19085.txt
# Renamed: S2-N1105M01338.txt → s2-n1105m01338.txt
# Renamed: S2-N1106M25504.txt → s2-n1106m25504.txt
# Renamed: S2-N1106M15534.txt → s2-n1106m15534.txt
# Renamed: S2-N1106M22904.txt → s2-n1106m22904.txt
# Renamed: S2-N1106M09834.txt → s2-n1106m09834.txt
# Renamed: S2-N0110M04225.txt → s2-n0110m04225.txt
# Renamed: S2-N1106M10195.txt → s2-n1106m10195.txt
# Renamed: S2-N1106M22592.txt → s2-n1106m22592.txt
# Renamed: S2-N1001M00509.txt → s2-n1001m00509.txt
# Renamed: S2-N1106M13299.txt → s2-n1106m13299.txt
# Renamed: S2-N1106M28332.txt → s2-n1106m28332.txt
# Renamed: S2-N0108M22160.txt → s2-n0108m22160.txt
# Renamed: S2-N1106M09073.txt → s2-n1106m09073.txt
# Renamed: S2-N2104M18511.txt → s2-n2104m18511.txt
# Renamed: S2-O1301M03559.txt → s2-o1301m03559.txt
# Renamed: S2-N1106M15105.txt → s2-n1106m15105.txt
# Renamed: S2-N1105M08826.txt → s2-n1105m08826.txt
# Renamed: S2-N1105M00935.txt → s2-n1105m00935.txt
# Renamed: S2-N1106M13676.txt → s2-n1106m13676.txt
# Renamed: S2-N1106M07504.txt → s2-n1106m07504.txt
# Renamed: S2-N1105M11432.txt → s2-n1105m11432.txt
# Renamed: S2-N1104M00747.txt → s2-n1104m00747.txt
# Renamed: S2-N1106M18067.txt → s2-n1106m18067.txt
# Renamed: S2-N1106M06880.txt → s2-n1106m06880.txt
# Renamed: S2-N1106M02505.txt → s2-n1106m02505.txt
# Renamed: S2-N1402M01911.txt → s2-n1402m01911.txt
# Renamed: S2-O1103M00269.txt → s2-o1103m00269.txt
# Renamed: S2-N1105M27167.txt → s2-n1105m27167.txt
# Renamed: S2-N1105M08516.txt → s2-n1105m08516.txt
# Renamed: S2-N1106M14789.txt → s2-n1106m14789.txt
# Renamed: S2-N1001M04125.txt → s2-n1001m04125.txt
# Renamed: S2-N1105M09404.txt → s2-n1105m09404.txt
# Renamed: S2-N0108M14723.txt → s2-n0108m14723.txt
# Renamed: S2-N0109M35972.txt → s2-n0109m35972.txt
# Renamed: S2-N1106M00221.txt → s2-n1106m00221.txt
# Renamed: S2-N1106M25389.txt → s2-n1106m25389.txt
# Renamed: S2-N1105M09716.txt → s2-n1105m09716.txt
# Renamed: S2-N0109M04813.txt → s2-n0109m04813.txt
# Renamed: S2-O1301M04185.txt → s2-o1301m04185.txt
# Renamed: S2-N1105M03803.txt → s2-n1105m03803.txt
# Renamed: S2-N1106M06520.txt → s2-n1106m06520.txt
# Renamed: S2-N1106M20831.txt → s2-n1106m20831.txt
# Renamed: S2-N1106M24543.txt → s2-n1106m24543.txt
# Renamed: S2-N1105M00307.txt → s2-n1105m00307.txt
# Renamed: S2-N1001M02803.txt → s2-n1001m02803.txt
# Renamed: S2-N1001M01925.txt → s2-n1001m01925.txt
# Renamed: S2-N1105M26982.txt → s2-n1105m26982.txt
# Renamed: S2-N1106M01555.txt → s2-n1106m01555.txt
# Renamed: S2-N0110M00113.txt → s2-n0110m00113.txt
# Renamed: S2-N2104M21866.txt → s2-n2104m21866.txt
# Renamed: S2-N1106M20279.txt → s2-n1106m20279.txt
# Renamed: S2-O1301M01470.txt → s2-o1301m01470.txt
# Renamed: S2-N1105M01053.txt → s2-n1105m01053.txt
# Renamed: S2-N1105M01671.txt → s2-n1105m01671.txt
# Renamed: S2-N0109M42011.txt → s2-n0109m42011.txt
# Renamed: S2-N2104M18048.txt → s2-n2104m18048.txt
# Renamed: S2-N1106M16492.txt → s2-n1106m16492.txt
# Renamed: S2-N1106M08054.txt → s2-n1106m08054.txt
# Renamed: S2-N0109M09526.txt → s2-n0109m09526.txt
# Renamed: S2-N1106M29561.txt → s2-n1106m29561.txt
# Renamed: S2-N1105M07385.txt → s2-n1105m07385.txt
# Renamed: S2-N1105M08008.txt → s2-n1105m08008.txt
# Renamed: S2-N1106M10627.txt → s2-n1106m10627.txt
# Renamed: S2-N0108M06254.txt → s2-n0108m06254.txt
# Renamed: S2-N1106M12382.txt → s2-n1106m12382.txt
# Renamed: S2-N1106M05972.txt → s2-n1106m05972.txt
# Renamed: S2-N0108M20441.txt → s2-n0108m20441.txt
# Renamed: S2-O1301M00125.txt → s2-o1301m00125.txt
# Renamed: S2-N1104M01349.txt → s2-n1104m01349.txt
# Renamed: S2-N1105M08353.txt → s2-n1105m08353.txt
# Renamed: S2-O1301M03721.txt → s2-o1301m03721.txt
# Renamed: S2-N1106M26070.txt → s2-n1106m26070.txt
# Renamed: S2-N1106M22799.txt → s2-n1106m22799.txt
# Renamed: S2-N1106M23778.txt → s2-n1106m23778.txt
# Renamed: S2-N1106M17991.txt → s2-n1106m17991.txt
# Renamed: S2-N1106M12399.txt → s2-n1106m12399.txt
# Renamed: S2-N1106M13207.txt → s2-n1106m13207.txt
# Renamed: S2-N2104M26658.txt → s2-n2104m26658.txt
# Renamed: S2-N1106M30167.txt → s2-n1106m30167.txt
# Renamed: S2-N1106M03773.txt → s2-n1106m03773.txt
# Renamed: S2-N1105M03574.txt → s2-n1105m03574.txt
# Renamed: S2-N1106M15493.txt → s2-n1106m15493.txt
# Renamed: S2-N1106M14600.txt → s2-n1106m14600.txt
# Renamed: S2-N1106M12983.txt → s2-n1106m12983.txt
# Renamed: S2-N1106M04470.txt → s2-n1106m04470.txt
# Renamed: S2-N1105M27313.txt → s2-n1105m27313.txt
# Renamed: S2-N1401M03434.txt → s2-n1401m03434.txt
# Renamed: S2-N1106M07917.txt → s2-n1106m07917.txt
# Renamed: S2-N1106M00803.txt → s2-n1106m00803.txt
# Renamed: S2-N2104M18665.txt → s2-n2104m18665.txt
# Renamed: S2-N1106M01091.txt → s2-n1106m01091.txt
# Renamed: S2-N0109M08690.txt → s2-n0109m08690.txt
# Renamed: S2-N1106M28013.txt → s2-n1106m28013.txt
# Renamed: S2-N1106M09484.txt → s2-n1106m09484.txt
# Renamed: S2-N1106M14453.txt → s2-n1106m14453.txt
# Renamed: S2-N1106M12328.txt → s2-n1106m12328.txt
# Renamed: S2-N1106M14607.txt → s2-n1106m14607.txt
# Renamed: S2-N1106M26875.txt → s2-n1106m26875.txt
# Renamed: S2-N1106M15486.txt → s2-n1106m15486.txt
# Renamed: S2-N1105M23069.txt → s2-n1105m23069.txt
# Renamed: S2-N1106M19809.txt → s2-n1106m19809.txt
# Renamed: S2-N1106M09280.txt → s2-n1106m09280.txt
# Renamed: S2-N1106M22100.txt → s2-n1106m22100.txt
# Renamed: S2-N1402M06893.txt → s2-n1402m06893.txt
# Renamed: S2-N1106M20875.txt → s2-n1106m20875.txt
# Renamed: S2-N1106M20858.txt → s2-n1106m20858.txt
# Renamed: S2-N0109M14386.txt → s2-n0109m14386.txt
# Renamed: S2-N1105M18150.txt → s2-n1105m18150.txt
# Renamed: S2-N1206M07011.txt → s2-n1206m07011.txt
# Renamed: S2-N1105M08870.txt → s2-n1105m08870.txt
# Renamed: S2-N1105M00132.txt → s2-n1105m00132.txt
# Renamed: S2-N2104M26040.txt → s2-n2104m26040.txt
# Renamed: S2-N1106M16128.txt → s2-n1106m16128.txt
# Renamed: S2-O1301M04056.txt → s2-o1301m04056.txt
# Renamed: S2-N0110M02709.txt → s2-n0110m02709.txt
# Renamed: S2-N1401M02428.txt → s2-n1401m02428.txt
# Renamed: S2-N1401M01210.txt → s2-n1401m01210.txt
# Renamed: S2-O1103M00265.txt → s2-o1103m00265.txt
# Renamed: S2-N1402M06725.txt → s2-n1402m06725.txt
# Renamed: S2-N1106M09726.txt → s2-n1106m09726.txt
# Renamed: S2-O1301M01283.txt → s2-o1301m01283.txt
# Renamed: S2-N1402M10960.txt → s2-n1402m10960.txt
# Renamed: S2-N1401M00690.txt → s2-n1401m00690.txt
# Renamed: S2-N1106M18011.txt → s2-n1106m18011.txt
# Renamed: S2-N1105M06076.txt → s2-n1105m06076.txt
# Renamed: S2-N1106M00594.txt → s2-n1106m00594.txt
# Renamed: S2-N1106M07950.txt → s2-n1106m07950.txt
# Renamed: S2-N1106M22840.txt → s2-n1106m22840.txt
# Renamed: S2-N1106M03542.txt → s2-n1106m03542.txt
# Renamed: S2-N1105M01779.txt → s2-n1105m01779.txt
# Renamed: S2-N1106M17366.txt → s2-n1106m17366.txt
# Renamed: S2-N1106M05697.txt → s2-n1106m05697.txt
# Renamed: S2-O1301M01383.txt → s2-o1301m01383.txt
# Renamed: S2-N1106M25098.txt → s2-n1106m25098.txt
# Renamed: S2-N1104M02343.txt → s2-n1104m02343.txt
# Renamed: S2-N0108M21004.txt → s2-n0108m21004.txt
# Renamed: S2-N1402M11537.txt → s2-n1402m11537.txt
# Renamed: S2-N1106M09775.txt → s2-n1106m09775.txt
# Renamed: S2-N0108M18550.txt → s2-n0108m18550.txt
# Renamed: S2-N1206M00952.txt → s2-n1206m00952.txt
# Renamed: S2-O1301M01125.txt → s2-o1301m01125.txt
# Renamed: S2-N1105M25878.txt → s2-n1105m25878.txt
# Renamed: S2-N0110M07075.txt → s2-n0110m07075.txt
# Renamed: S2-N1106M23491.txt → s2-n1106m23491.txt
# Renamed: S2-N1106M28811.txt → s2-n1106m28811.txt
# Renamed: S2-N0109M03080.txt → s2-n0109m03080.txt
# Renamed: S2-N1402M02207.txt → s2-n1402m02207.txt
# Renamed: S2-N1106M18500.txt → s2-n1106m18500.txt
# Renamed: S2-N1106M02678.txt → s2-n1106m02678.txt
# Renamed: S2-N1106M28618.txt → s2-n1106m28618.txt
# Renamed: S2-N1106M23523.txt → s2-n1106m23523.txt
# Renamed: S2-O1302M00095.txt → s2-o1302m00095.txt
# Renamed: S2-N1106M02303.txt → s2-n1106m02303.txt
# Renamed: S2-N0109M37377.txt → s2-n0109m37377.txt
# Renamed: S2-N1106M10509.txt → s2-n1106m10509.txt
# Renamed: S2-N1104M02744.txt → s2-n1104m02744.txt
# Renamed: S2-N1106M20170.txt → s2-n1106m20170.txt
# Renamed: S2-N1206M23349.txt → s2-n1206m23349.txt
# Renamed: S2-N1001M01250.txt → s2-n1001m01250.txt
# Renamed: S2-N1001M01776.txt → s2-n1001m01776.txt
# Renamed: S2-N1401M03442.txt → s2-n1401m03442.txt
# Renamed: S2-N1402M00906.txt → s2-n1402m00906.txt
# Renamed: S2-N1106M28157.txt → s2-n1106m28157.txt
# Renamed: S2-N1105M03109.txt → s2-n1105m03109.txt
# Renamed: S2-N1105M07321.txt → s2-n1105m07321.txt
# Renamed: S2-N1206M04445.txt → s2-n1206m04445.txt
# Renamed: S2-N1106M05775.txt → s2-n1106m05775.txt
# Renamed: S2-N1105M24053.txt → s2-n1105m24053.txt
# Renamed: S2-O1301M00312.txt → s2-o1301m00312.txt
# Renamed: S2-O1103M05811.txt → s2-o1103m05811.txt
# Renamed: S2-N0110M03741.txt → s2-n0110m03741.txt
# Renamed: S2-N1106M11580.txt → s2-n1106m11580.txt
# Renamed: S2-O1103M06262.txt → s2-o1103m06262.txt
# Renamed: S2-N0109M08009.txt → s2-n0109m08009.txt
# Renamed: S2-O1301M01076.txt → s2-o1301m01076.txt
# Renamed: S2-N1105M03557.txt → s2-n1105m03557.txt
# Renamed: S2-N1402M05782.txt → s2-n1402m05782.txt
# Renamed: S2-N1106M01164.txt → s2-n1106m01164.txt
# Renamed: S2-N1105M18409.txt → s2-n1105m18409.txt
# Renamed: S2-N1105M11683.txt → s2-n1105m11683.txt
# Renamed: S2-N1106M07615.txt → s2-n1106m07615.txt
# Renamed: S2-N1001M04504.txt → s2-n1001m04504.txt
# Renamed: S2-N1206M02730.txt → s2-n1206m02730.txt
# Renamed: S2-N2104M25532.txt → s2-n2104m25532.txt
# Renamed: S2-N1106M11256.txt → s2-n1106m11256.txt
# Renamed: S2-N1206M06443.txt → s2-n1206m06443.txt
# Renamed: S2-N1106M00418.txt → s2-n1106m00418.txt
# Renamed: S2-N1106M01022.txt → s2-n1106m01022.txt
# Renamed: S2-N1106M15141.txt → s2-n1106m15141.txt
# Renamed: S2-N1106M19111.txt → s2-n1106m19111.txt
# Renamed: S2-N1402M03312.txt → s2-n1402m03312.txt
# Renamed: S2-N1106M14451.txt → s2-n1106m14451.txt
# Renamed: S2-N1105M00347.txt → s2-n1105m00347.txt
# Renamed: S2-N1206M05839.txt → s2-n1206m05839.txt
# Renamed: S2-N1401M01879.txt → s2-n1401m01879.txt
# Renamed: S2-N1106M26575.txt → s2-n1106m26575.txt
# Renamed: S2-N1105M04523.txt → s2-n1105m04523.txt
# Renamed: S2-O1302M00385.txt → s2-o1302m00385.txt
# Renamed: S2-N1105M05971.txt → s2-n1105m05971.txt
# Renamed: S2-N1106M07772.txt → s2-n1106m07772.txt
# Renamed: S2-N1104M01579.txt → s2-n1104m01579.txt
# Renamed: S2-N1106M05925.txt → s2-n1106m05925.txt
# Renamed: S2-N1106M02376.txt → s2-n1106m02376.txt
# Renamed: S2-N1401M00156.txt → s2-n1401m00156.txt
# Renamed: S2-N1106M01396.txt → s2-n1106m01396.txt
# Renamed: S2-N1106M24455.txt → s2-n1106m24455.txt
# Renamed: S2-N1105M00106.txt → s2-n1105m00106.txt
# Renamed: S2-N1106M17503.txt → s2-n1106m17503.txt
# Renamed: S2-N0108M21040.txt → s2-n0108m21040.txt
# Renamed: S2-N1106M13978.txt → s2-n1106m13978.txt
# Renamed: S2-N0110M05260.txt → s2-n0110m05260.txt
# Renamed: S2-N1105M04569.txt → s2-n1105m04569.txt
# Renamed: S2-N1106M01389.txt → s2-n1106m01389.txt
# Renamed: S2-N1105M10840.txt → s2-n1105m10840.txt
# Renamed: S2-N0109M06994.txt → s2-n0109m06994.txt
# Renamed: S2-O1301M01947.txt → s2-o1301m01947.txt
# Renamed: S2-N1105M27095.txt → s2-n1105m27095.txt
# Renamed: S2-N1105M07961.txt → s2-n1105m07961.txt
# Renamed: S2-N1106M20047.txt → s2-n1106m20047.txt
# Renamed: S2-O1302M00028.txt → s2-o1302m00028.txt
# Renamed: S2-N1106M18204.txt → s2-n1106m18204.txt
# Renamed: S2-N1001M01231.txt → s2-n1001m01231.txt
# Renamed: S2-N1106M18055.txt → s2-n1106m18055.txt
# Renamed: S2-N1402M02626.txt → s2-n1402m02626.txt
# Renamed: S2-N1105M04409.txt → s2-n1105m04409.txt
# Renamed: S2-N0108M18442.txt → s2-n0108m18442.txt
# Renamed: S2-N1106M23827.txt → s2-n1106m23827.txt
# Renamed: S2-N1106M25843.txt → s2-n1106m25843.txt
# Renamed: S2-N1001M01421.txt → s2-n1001m01421.txt
# Renamed: S2-N0108M27946.txt → s2-n0108m27946.txt
# Renamed: S2-N1105M05633.txt → s2-n1105m05633.txt
# Renamed: S2-N1105M21119.txt → s2-n1105m21119.txt
# Renamed: S2-N0109M08477.txt → s2-n0109m08477.txt
# Renamed: S2-N2104M17309.txt → s2-n2104m17309.txt
# Renamed: S2-O1301M03901.txt → s2-o1301m03901.txt
# Renamed: S2-N1106M24510.txt → s2-n1106m24510.txt
# Renamed: S2-N1105M03118.txt → s2-n1105m03118.txt
# Renamed: S2-N1105M24310.txt → s2-n1105m24310.txt
# Renamed: S2-N1106M12590.txt → s2-n1106m12590.txt
# Renamed: S2-O1301M03962.txt → s2-o1301m03962.txt
# Renamed: S2-O1301M04236.txt → s2-o1301m04236.txt
# Renamed: S2-N0109M34607.txt → s2-n0109m34607.txt
# Renamed: S2-N2103M60879.txt → s2-n2103m60879.txt
# Renamed: S2-N1106M00625.txt → s2-n1106m00625.txt
# Renamed: S2-N1106M26129.txt → s2-n1106m26129.txt
# Renamed: S2-N1106M15494.txt → s2-n1106m15494.txt
# Renamed: S2-N1105M24697.txt → s2-n1105m24697.txt
# Renamed: S2-N2104M24376.txt → s2-n2104m24376.txt
# Renamed: S2-N0110M02041.txt → s2-n0110m02041.txt
# Renamed: S2-N1105M08816.txt → s2-n1105m08816.txt
# Renamed: S2-N1105M10286.txt → s2-n1105m10286.txt
# Renamed: S2-O1301M03035.txt → s2-o1301m03035.txt
# Renamed: S2-N1106M00229.txt → s2-n1106m00229.txt
# Renamed: S2-N0109M13763.txt → s2-n0109m13763.txt
# Renamed: S2-N1106M17655.txt → s2-n1106m17655.txt
# Renamed: S2-N1105M02079.txt → s2-n1105m02079.txt
# Renamed: S2-N1106M21515.txt → s2-n1106m21515.txt
# Renamed: S2-N2103M61775.txt → s2-n2103m61775.txt
# Renamed: S2-N0109M30338.txt → s2-n0109m30338.txt
# Renamed: S2-N0109M33857.txt → s2-n0109m33857.txt
# Renamed: S2-N1105M07090.txt → s2-n1105m07090.txt
# Renamed: S2-N0110M01214.txt → s2-n0110m01214.txt
# Renamed: S2-N1105M17762.txt → s2-n1105m17762.txt
# Renamed: S2-N1106M09188.txt → s2-n1106m09188.txt
# Renamed: S2-N0109M09719.txt → s2-n0109m09719.txt
# Renamed: S2-N1106M03664.txt → s2-n1106m03664.txt
# Renamed: S2-N2104M20022.txt → s2-n2104m20022.txt
# Renamed: S2-N1106M21146.txt → s2-n1106m21146.txt
# Renamed: S2-N1106M13752.txt → s2-n1106m13752.txt
# Renamed: S2-N1106M02039.txt → s2-n1106m02039.txt
# Renamed: S2-N2104M16882.txt → s2-n2104m16882.txt
# Renamed: S2-N2104M21186.txt → s2-n2104m21186.txt
# Renamed: S2-N2104M18085.txt → s2-n2104m18085.txt
# Renamed: S2-N1106M00983.txt → s2-n1106m00983.txt
# Renamed: S2-N1106M00623.txt → s2-n1106m00623.txt
# Renamed: S2-N0108M17826.txt → s2-n0108m17826.txt
# Renamed: S2-N0108M23359.txt → s2-n0108m23359.txt
# Renamed: S2-N1106M03703.txt → s2-n1106m03703.txt
# Renamed: S2-N1106M18117.txt → s2-n1106m18117.txt
# Renamed: S2-N0109M13574.txt → s2-n0109m13574.txt
# Renamed: S2-N1106M21779.txt → s2-n1106m21779.txt
# Renamed: S2-N1105M08941.txt → s2-n1105m08941.txt
# Renamed: S2-N1402M01316.txt → s2-n1402m01316.txt
# Renamed: S2-O1302M00179.txt → s2-o1302m00179.txt
# Renamed: S2-N1206M12707.txt → s2-n1206m12707.txt
# Renamed: S2-N1106M15143.txt → s2-n1106m15143.txt
# Renamed: S2-N0109M14513.txt → s2-n0109m14513.txt
# Renamed: S2-N1106M03980.txt → s2-n1106m03980.txt
# Renamed: S2-N1105M03698.txt → s2-n1105m03698.txt
# Renamed: S2-N1105M10868.txt → s2-n1105m10868.txt
# Renamed: S2-N1402M01757.txt → s2-n1402m01757.txt
# Renamed: S2-N1106M23740.txt → s2-n1106m23740.txt
# Renamed: S2-N1106M07924.txt → s2-n1106m07924.txt
# Renamed: S2-N0109M36511.txt → s2-n0109m36511.txt
# Renamed: S2-N1106M19693.txt → s2-n1106m19693.txt
# Renamed: S2-N1106M14313.txt → s2-n1106m14313.txt
# Renamed: S2-N1106M11606.txt → s2-n1106m11606.txt
# Renamed: S2-N1106M17422.txt → s2-n1106m17422.txt
# Renamed: S2-N1402M04405.txt → s2-n1402m04405.txt
# Renamed: S2-N1106M24731.txt → s2-n1106m24731.txt
# Renamed: S2-N1402M09730.txt → s2-n1402m09730.txt
# Renamed: S2-N1106M14034.txt → s2-n1106m14034.txt
# Renamed: S2-N0110M08872.txt → s2-n0110m08872.txt
# Renamed: S2-N1106M17963.txt → s2-n1106m17963.txt
# Renamed: S2-N1106M04168.txt → s2-n1106m04168.txt
# Renamed: S2-N1106M27950.txt → s2-n1106m27950.txt
# Renamed: S2-N0108M16200.txt → s2-n0108m16200.txt
# Renamed: S2-N1106M12884.txt → s2-n1106m12884.txt
# Renamed: S2-N0110M04859.txt → s2-n0110m04859.txt
# Renamed: S2-N1106M15661.txt → s2-n1106m15661.txt
# Renamed: S2-N1106M18876.txt → s2-n1106m18876.txt
# Renamed: S2-N1106M27478.txt → s2-n1106m27478.txt
# Renamed: S2-N1105M10961.txt → s2-n1105m10961.txt
# Renamed: S2-N1106M23268.txt → s2-n1106m23268.txt
# Renamed: S2-N1104M02196.txt → s2-n1104m02196.txt
# Renamed: S2-N1206M02968.txt → s2-n1206m02968.txt
# Renamed: S2-N1206M07003.txt → s2-n1206m07003.txt
# Renamed: S2-N1105M25630.txt → s2-n1105m25630.txt
# Renamed: S2-N1106M14825.txt → s2-n1106m14825.txt
# Renamed: S2-N1106M16523.txt → s2-n1106m16523.txt
# Renamed: S2-N0108M20028.txt → s2-n0108m20028.txt
# Renamed: S2-N1106M18505.txt → s2-n1106m18505.txt
# Renamed: S2-N1206M01443.txt → s2-n1206m01443.txt
# Renamed: S2-N0110M02240.txt → s2-n0110m02240.txt
# Renamed: S2-N1001M02851.txt → s2-n1001m02851.txt
# Renamed: S2-N1106M22326.txt → s2-n1106m22326.txt
# Renamed: S2-N1106M02045.txt → s2-n1106m02045.txt
# Renamed: S2-N1106M07084.txt → s2-n1106m07084.txt
# Renamed: S2-N1105M00437.txt → s2-n1105m00437.txt
# Renamed: S2-N1106M23277.txt → s2-n1106m23277.txt
# Renamed: S2-N1105M20433.txt → s2-n1105m20433.txt
# Renamed: S2-N1401M04020.txt → s2-n1401m04020.txt
# Renamed: S2-N1105M00852.txt → s2-n1105m00852.txt
# Renamed: S2-N1106M08597.txt → s2-n1106m08597.txt
# Renamed: S2-N1106M00404.txt → s2-n1106m00404.txt
# Renamed: S2-N0110M04973.txt → s2-n0110m04973.txt
# Renamed: S2-N1105M20559.txt → s2-n1105m20559.txt
# Renamed: S2-N1402M10793.txt → s2-n1402m10793.txt
# Renamed: S2-N1105M27566.txt → s2-n1105m27566.txt
# Renamed: S2-N1105M05269.txt → s2-n1105m05269.txt
# Renamed: S2-N1106M03434.txt → s2-n1106m03434.txt
# Renamed: S2-N1402M11656.txt → s2-n1402m11656.txt
# Renamed: S2-N1105M04426.txt → s2-n1105m04426.txt
# Renamed: S2-N1104M00521.txt → s2-n1104m00521.txt
# Renamed: S2-N1105M04660.txt → s2-n1105m04660.txt
# Renamed: S2-N0109M14691.txt → s2-n0109m14691.txt
# Renamed: S2-N1106M22541.txt → s2-n1106m22541.txt
# Renamed: S2-N2103M22383.txt → s2-n2103m22383.txt
# Renamed: S2-N1106M16603.txt → s2-n1106m16603.txt
# Renamed: S2-N0110M05028.txt → s2-n0110m05028.txt
# Renamed: S2-N1106M21604.txt → s2-n1106m21604.txt
# Renamed: S2-N2104M15694.txt → s2-n2104m15694.txt
# Renamed: S2-N1106M03738.txt → s2-n1106m03738.txt
# Renamed: S2-N1105M07447.txt → s2-n1105m07447.txt
# Renamed: S2-N1106M10918.txt → s2-n1106m10918.txt
# Renamed: S2-N1106M15244.txt → s2-n1106m15244.txt
# Renamed: S2-N1402M02540.txt → s2-n1402m02540.txt
# Renamed: S2-N0110M05650.txt → s2-n0110m05650.txt
# Renamed: S2-N1106M09455.txt → s2-n1106m09455.txt
# Renamed: S2-N1206M06274.txt → s2-n1206m06274.txt
# Renamed: S2-N0109M49491.txt → s2-n0109m49491.txt
# Renamed: S2-N1106M17401.txt → s2-n1106m17401.txt
# Renamed: S2-N1106M00083.txt → s2-n1106m00083.txt
# Renamed: S2-N1106M01356.txt → s2-n1106m01356.txt
# Renamed: S2-N1001M02198.txt → s2-n1001m02198.txt
# Renamed: S2-N1105M00522.txt → s2-n1105m00522.txt
# Renamed: S2-N1106M07421.txt → s2-n1106m07421.txt
# Renamed: S2-N2104M19354.txt → s2-n2104m19354.txt
# Renamed: S2-N1106M29050.txt → s2-n1106m29050.txt
# Renamed: S2-N1106M02947.txt → s2-n1106m02947.txt
# Renamed: S2-N2104M26444.txt → s2-n2104m26444.txt
# Renamed: S2-N1105M09443.txt → s2-n1105m09443.txt
# Renamed: S2-N0108M20897.txt → s2-n0108m20897.txt
# Renamed: S2-N1106M12376.txt → s2-n1106m12376.txt
# Renamed: S2-N1106M16287.txt → s2-n1106m16287.txt
# Renamed: S2-N1105M05207.txt → s2-n1105m05207.txt
# Renamed: S2-N1402M03314.txt → s2-n1402m03314.txt
# Renamed: S2-N1106M27120.txt → s2-n1106m27120.txt
# Renamed: S2-N1106M22213.txt → s2-n1106m22213.txt
# Renamed: S2-N1106M20203.txt → s2-n1106m20203.txt
# Renamed: S2-N1001M00216.txt → s2-n1001m00216.txt
# Renamed: S2-N1105M01970.txt → s2-n1105m01970.txt
# Renamed: S2-N1106M19000.txt → s2-n1106m19000.txt
# Renamed: S2-N0110M03097.txt → s2-n0110m03097.txt
# Renamed: S2-N1105M01061.txt → s2-n1105m01061.txt
# Renamed: S2-N1106M13995.txt → s2-n1106m13995.txt
# Renamed: S2-N2104M14872.txt → s2-n2104m14872.txt
# Renamed: S2-N1001M02090.txt → s2-n1001m02090.txt
# Renamed: S2-N1106M22422.txt → s2-n1106m22422.txt
# Renamed: S2-N1106M05382.txt → s2-n1106m05382.txt
# Renamed: S2-N1106M14546.txt → s2-n1106m14546.txt
# Renamed: S2-N1106M07409.txt → s2-n1106m07409.txt
# Renamed: S2-N1106M06408.txt → s2-n1106m06408.txt
# Renamed: S2-N1105M07399.txt → s2-n1105m07399.txt
# Renamed: S2-N1105M01805.txt → s2-n1105m01805.txt
# Renamed: S2-N1106M22723.txt → s2-n1106m22723.txt
# Renamed: S2-O1302M00271.txt → s2-o1302m00271.txt
# Renamed: S2-O1301M02874.txt → s2-o1301m02874.txt
# Renamed: S2-N1206M23981.txt → s2-n1206m23981.txt
# Renamed: S2-N1106M14337.txt → s2-n1106m14337.txt
# Renamed: S2-N1105M01444.txt → s2-n1105m01444.txt
# Renamed: S2-O1103M01638.txt → s2-o1103m01638.txt
# Renamed: S2-N1001M02010.txt → s2-n1001m02010.txt
# Renamed: S2-N1105M18273.txt → s2-n1105m18273.txt
# Renamed: S2-N1106M02318.txt → s2-n1106m02318.txt
# Renamed: S2-N1001M04359.txt → s2-n1001m04359.txt
# Renamed: S2-N1106M18432.txt → s2-n1106m18432.txt
# Renamed: S2-N1106M16037.txt → s2-n1106m16037.txt
# Renamed: S2-N1106M20359.txt → s2-n1106m20359.txt
# Renamed: S2-N1104M01035.txt → s2-n1104m01035.txt
# Renamed: S2-N0110M00768.txt → s2-n0110m00768.txt
# Renamed: S2-N1106M25730.txt → s2-n1106m25730.txt
# Renamed: S2-N1105M00229.txt → s2-n1105m00229.txt
# Renamed: S2-N1106M20039.txt → s2-n1106m20039.txt
# Renamed: S2-N1106M14467.txt → s2-n1106m14467.txt
# Renamed: S2-N1105M06054.txt → s2-n1105m06054.txt
# Renamed: S2-N1106M03518.txt → s2-n1106m03518.txt
# Renamed: S2-N1106M07309.txt → s2-n1106m07309.txt
# Renamed: S2-O1101M04827.txt → s2-o1101m04827.txt
# Renamed: S2-N1106M06671.txt → s2-n1106m06671.txt
# Renamed: S2-N1106M03129.txt → s2-n1106m03129.txt
# Renamed: S2-N1402M03216.txt → s2-n1402m03216.txt
# Renamed: S2-N1106M09053.txt → s2-n1106m09053.txt
# Renamed: S2-N1106M00966.txt → s2-n1106m00966.txt
# Renamed: S2-N1105M26979.txt → s2-n1105m26979.txt
# Renamed: S2-N1106M16247.txt → s2-n1106m16247.txt
# Renamed: S2-N0109M39248.txt → s2-n0109m39248.txt
# Renamed: S2-N1001M00763.txt → s2-n1001m00763.txt
# Renamed: S2-N1105M06865.txt → s2-n1105m06865.txt
# Renamed: S2-N1106M16106.txt → s2-n1106m16106.txt
# Renamed: S2-N1105M07563.txt → s2-n1105m07563.txt
# Renamed: S2-O1301M02344.txt → s2-o1301m02344.txt
# Renamed: S2-N1106M06624.txt → s2-n1106m06624.txt
# Renamed: S2-N0110M03344.txt → s2-n0110m03344.txt
# Renamed: S2-N1106M18091.txt → s2-n1106m18091.txt
# Renamed: S2-N1106M19545.txt → s2-n1106m19545.txt
# Renamed: S2-N1106M08608.txt → s2-n1106m08608.txt
# Renamed: S2-N1104M01181.txt → s2-n1104m01181.txt
# Renamed: S2-N1106M15049.txt → s2-n1106m15049.txt
# Renamed: S2-N1106M00057.txt → s2-n1106m00057.txt
# Renamed: S2-N1106M10371.txt → s2-n1106m10371.txt
# Renamed: S2-O1101M08297.txt → s2-o1101m08297.txt
# Renamed: S2-N1106M27737.txt → s2-n1106m27737.txt
# Renamed: S2-N1105M10077.txt → s2-n1105m10077.txt
# Renamed: S2-N1106M10713.txt → s2-n1106m10713.txt
# Renamed: S2-N1106M08465.txt → s2-n1106m08465.txt
# Renamed: S2-N1106M29501.txt → s2-n1106m29501.txt
# Renamed: S2-N1206M24126.txt → s2-n1206m24126.txt
# Renamed: S2-N1106M19877.txt → s2-n1106m19877.txt
# Renamed: S2-O1301M04196.txt → s2-o1301m04196.txt
# Renamed: S2-N1106M21306.txt → s2-n1106m21306.txt
# Renamed: S2-N0109M40544.txt → s2-n0109m40544.txt
# Renamed: S2-N1106M01130.txt → s2-n1106m01130.txt
# Renamed: S2-N1106M00128.txt → s2-n1106m00128.txt
# Renamed: S2-N1106M15353.txt → s2-n1106m15353.txt
# Renamed: S2-N1106M14981.txt → s2-n1106m14981.txt
# Renamed: S2-N1106M15168.txt → s2-n1106m15168.txt
# Renamed: S2-N1106M13645.txt → s2-n1106m13645.txt
# Renamed: S2-O1302M00348.txt → s2-o1302m00348.txt
# Renamed: S2-N1106M20637.txt → s2-n1106m20637.txt
# Renamed: S2-N1106M20824.txt → s2-n1106m20824.txt
# Renamed: S2-N1105M26493.txt → s2-n1105m26493.txt
# Renamed: S2-N1106M23045.txt → s2-n1106m23045.txt
# Renamed: S2-N0109M37899.txt → s2-n0109m37899.txt
# Renamed: S2-N1106M22931.txt → s2-n1106m22931.txt
# Renamed: S2-O1301M04099.txt → s2-o1301m04099.txt
# Renamed: S2-N1106M10525.txt → s2-n1106m10525.txt
# Renamed: S2-N1105M22934.txt → s2-n1105m22934.txt
# Renamed: S2-N1106M16807.txt → s2-n1106m16807.txt
# Renamed: S2-N1106M27717.txt → s2-n1106m27717.txt
# Renamed: S2-O1302M00686.txt → s2-o1302m00686.txt
# Renamed: S2-N0109M33954.txt → s2-n0109m33954.txt
# Renamed: S2-N1106M04871.txt → s2-n1106m04871.txt
# Renamed: S2-O1301M02873.txt → s2-o1301m02873.txt
# Renamed: S2-N1106M04593.txt → s2-n1106m04593.txt
# Renamed: S2-N1104M00343.txt → s2-n1104m00343.txt
# Renamed: S2-N0109M18018.txt → s2-n0109m18018.txt
# Renamed: S2-N1106M19492.txt → s2-n1106m19492.txt
# Renamed: S2-O1301M03447.txt → s2-o1301m03447.txt
# Renamed: S2-N1106M01177.txt → s2-n1106m01177.txt
# Renamed: S2-N1206M23937.txt → s2-n1206m23937.txt
# Renamed: S2-N0109M04972.txt → s2-n0109m04972.txt
# Renamed: S2-N1001M03172.txt → s2-n1001m03172.txt
# Renamed: S2-N1402M06764.txt → s2-n1402m06764.txt
# Renamed: S2-N1206M03835.txt → s2-n1206m03835.txt
# Renamed: S2-N1106M11763.txt → s2-n1106m11763.txt
# Renamed: S2-N0109M11757.txt → s2-n0109m11757.txt
# Renamed: S2-N1106M28755.txt → s2-n1106m28755.txt
# Renamed: S2-N1106M17681.txt → s2-n1106m17681.txt
# Renamed: S2-N1106M06595.txt → s2-n1106m06595.txt
# Renamed: S2-N1106M21209.txt → s2-n1106m21209.txt
# Renamed: S2-N1106M19599.txt → s2-n1106m19599.txt
# Renamed: S2-N1402M12030.txt → s2-n1402m12030.txt
# Renamed: S2-N1106M15085.txt → s2-n1106m15085.txt
# Renamed: S2-N1106M10272.txt → s2-n1106m10272.txt
# Renamed: S2-N1105M02724.txt → s2-n1105m02724.txt
# Renamed: S2-N1402M02782.txt → s2-n1402m02782.txt
# Renamed: S2-N2104M13933.txt → s2-n2104m13933.txt
# Renamed: S2-N1106M06643.txt → s2-n1106m06643.txt
# Renamed: S2-N1106M11224.txt → s2-n1106m11224.txt
# Renamed: S2-O1301M04472.txt → s2-o1301m04472.txt
# Renamed: S2-N0109M04820.txt → s2-n0109m04820.txt
# Renamed: S2-N1206M03945.txt → s2-n1206m03945.txt
# Renamed: S2-N1106M01928.txt → s2-n1106m01928.txt
# Renamed: S2-N1106M01534.txt → s2-n1106m01534.txt
# Renamed: S2-N1001M02853.txt → s2-n1001m02853.txt
# Renamed: S2-N1106M04492.txt → s2-n1106m04492.txt
# Renamed: S2-N1106M14979.txt → s2-n1106m14979.txt
# Renamed: S2-N1106M15042.txt → s2-n1106m15042.txt
# Renamed: S2-N1106M06338.txt → s2-n1106m06338.txt
# Renamed: S2-N1105M23976.txt → s2-n1105m23976.txt
# Renamed: S2-N1106M18169.txt → s2-n1106m18169.txt
# Renamed: S2-N1105M00244.txt → s2-n1105m00244.txt
# Renamed: S2-N1106M11679.txt → s2-n1106m11679.txt
# Renamed: S2-N1106M21518.txt → s2-n1106m21518.txt
# Renamed: S2-N1104M02518.txt → s2-n1104m02518.txt
# Renamed: S2-N1106M02247.txt → s2-n1106m02247.txt
# Renamed: S2-N1401M01846.txt → s2-n1401m01846.txt
# Renamed: S2-N1106M05821.txt → s2-n1106m05821.txt
# Renamed: S2-N1106M29066.txt → s2-n1106m29066.txt
# Renamed: S2-O1301M02195.txt → s2-o1301m02195.txt
# Renamed: S2-N0109M07353.txt → s2-n0109m07353.txt
# Renamed: S2-O1103M00264.txt → s2-o1103m00264.txt
# Renamed: S2-N1105M10037.txt → s2-n1105m10037.txt
# Renamed: S2-N1105M02188.txt → s2-n1105m02188.txt
# Renamed: S2-N2104M19955.txt → s2-n2104m19955.txt
# Renamed: S2-N1106M01149.txt → s2-n1106m01149.txt
# Renamed: S2-N1001M02480.txt → s2-n1001m02480.txt
# Renamed: S2-N1104M00363.txt → s2-n1104m00363.txt
# Renamed: S2-N1106M17929.txt → s2-n1106m17929.txt
# Renamed: S2-N1106M29646.txt → s2-n1106m29646.txt
# Renamed: S2-N1402M05732.txt → s2-n1402m05732.txt
# Renamed: S2-N2103M27396.txt → s2-n2103m27396.txt
# Renamed: S2-N1106M05694.txt → s2-n1106m05694.txt
# Renamed: S2-N1106M18222.txt → s2-n1106m18222.txt
# Renamed: S2-N0109M00939.txt → s2-n0109m00939.txt
# Renamed: S2-N1105M21867.txt → s2-n1105m21867.txt
# Renamed: S2-N1106M04180.txt → s2-n1106m04180.txt
# Renamed: S2-N2104M18978.txt → s2-n2104m18978.txt
# Renamed: S2-N1106M18004.txt → s2-n1106m18004.txt
# Renamed: S2-N0110M07749.txt → s2-n0110m07749.txt
# Renamed: S2-N1106M25121.txt → s2-n1106m25121.txt
# Renamed: S2-N1402M06395.txt → s2-n1402m06395.txt
# Renamed: S2-N1106M13001.txt → s2-n1106m13001.txt
# Renamed: S2-N1104M01695.txt → s2-n1104m01695.txt
# Renamed: S2-N1105M03578.txt → s2-n1105m03578.txt
# Renamed: S2-N1105M10004.txt → s2-n1105m10004.txt
# Renamed: S2-O1103M03947.txt → s2-o1103m03947.txt
# Renamed: S2-N1105M24000.txt → s2-n1105m24000.txt
# Renamed: S2-N1105M26544.txt → s2-n1105m26544.txt
# Renamed: S2-N1105M03619.txt → s2-n1105m03619.txt
# Renamed: S2-N1106M02558.txt → s2-n1106m02558.txt
# Renamed: S2-N0109M05711.txt → s2-n0109m05711.txt
# Renamed: S2-N1105M01790.txt → s2-n1105m01790.txt
# Renamed: S2-N1104M02923.txt → s2-n1104m02923.txt
# Renamed: S2-N1106M15418.txt → s2-n1106m15418.txt
# Renamed: S2-N0109M38965.txt → s2-n0109m38965.txt
# Renamed: S2-N1106M06007.txt → s2-n1106m06007.txt
# Renamed: S2-N1106M29530.txt → s2-n1106m29530.txt
# Renamed: S2-N1106M02348.txt → s2-n1106m02348.txt
# Renamed: S2-O1103M03946.txt → s2-o1103m03946.txt
# Renamed: S2-N1106M22230.txt → s2-n1106m22230.txt
# Renamed: S2-N1105M06615.txt → s2-n1105m06615.txt
# Renamed: S2-N1106M18689.txt → s2-n1106m18689.txt
# Renamed: S2-N1106M12990.txt → s2-n1106m12990.txt
# Renamed: S2-N1105M02937.txt → s2-n1105m02937.txt
# Renamed: S2-N1105M05676.txt → s2-n1105m05676.txt
# Renamed: S2-N1105M24153.txt → s2-n1105m24153.txt
# Renamed: S2-N1001M00339.txt → s2-n1001m00339.txt
# Renamed: S2-N1106M10604.txt → s2-n1106m10604.txt
# Renamed: S2-N1106M18103.txt → s2-n1106m18103.txt
# Renamed: S2-N1106M14671.txt → s2-n1106m14671.txt
# Renamed: S2-N1106M17087.txt → s2-n1106m17087.txt
# Renamed: S2-N1106M11824.txt → s2-n1106m11824.txt
# Renamed: S2-N1106M20707.txt → s2-n1106m20707.txt
# Renamed: S2-N1106M02249.txt → s2-n1106m02249.txt
# Renamed: S2-N1105M03204.txt → s2-n1105m03204.txt
# Renamed: S2-N1106M01467.txt → s2-n1106m01467.txt
# Renamed: S2-N0108M02918.txt → s2-n0108m02918.txt
# Renamed: S2-N1106M00363.txt → s2-n1106m00363.txt
# Renamed: S2-N1106M14525.txt → s2-n1106m14525.txt
# Renamed: S2-N1105M02600.txt → s2-n1105m02600.txt
# Renamed: S2-N1104M00587.txt → s2-n1104m00587.txt
# Renamed: S2-N1206M06750.txt → s2-n1206m06750.txt
# Renamed: S2-N1105M02565.txt → s2-n1105m02565.txt
# Renamed: S2-N0109M51755.txt → s2-n0109m51755.txt
# Renamed: S2-N1001M01371.txt → s2-n1001m01371.txt
# Renamed: S2-O1103M03790.txt → s2-o1103m03790.txt
# Renamed: S2-N1105M05881.txt → s2-n1105m05881.txt
# Renamed: S2-N1105M06221.txt → s2-n1105m06221.txt
# Renamed: S2-N1106M18301.txt → s2-n1106m18301.txt
# Renamed: S2-N1106M04295.txt → s2-n1106m04295.txt
# Renamed: S2-N1104M00965.txt → s2-n1104m00965.txt
# Renamed: S2-N1001M00748.txt → s2-n1001m00748.txt
# Renamed: S2-N1401M02309.txt → s2-n1401m02309.txt
# Renamed: S2-N1206M03583.txt → s2-n1206m03583.txt
# Renamed: S2-O1302M00154.txt → s2-o1302m00154.txt
# Renamed: S2-O1101M08313.txt → s2-o1101m08313.txt
# Renamed: S2-N1106M27549.txt → s2-n1106m27549.txt
# Renamed: S2-N1106M14422.txt → s2-n1106m14422.txt
# Renamed: S2-N1105M08921.txt → s2-n1105m08921.txt
# Renamed: S2-N1106M06089.txt → s2-n1106m06089.txt
# Renamed: S2-N1106M07846.txt → s2-n1106m07846.txt
# Renamed: S2-N1106M22357.txt → s2-n1106m22357.txt
# Renamed: S2-N1106M16756.txt → s2-n1106m16756.txt
# Renamed: S2-N0109M07870.txt → s2-n0109m07870.txt
# Renamed: S2-N1206M23459.txt → s2-n1206m23459.txt
# Renamed: S2-N1106M25042.txt → s2-n1106m25042.txt
# Renamed: S2-N1106M07177.txt → s2-n1106m07177.txt
# Renamed: S2-N1105M02347.txt → s2-n1105m02347.txt
# Renamed: S2-N1106M05608.txt → s2-n1106m05608.txt
# Renamed: S2-N1106M18945.txt → s2-n1106m18945.txt
# Renamed: S2-N1106M06725.txt → s2-n1106m06725.txt
# Renamed: S2-N0109M04423.txt → s2-n0109m04423.txt
# Renamed: S2-O1101M00159.txt → s2-o1101m00159.txt
# Renamed: S2-N1106M03312.txt → s2-n1106m03312.txt
# Renamed: S2-N2104M13762.txt → s2-n2104m13762.txt
# Renamed: S2-N1106M14885.txt → s2-n1106m14885.txt
# Renamed: S2-N1105M03175.txt → s2-n1105m03175.txt
# Renamed: S2-N1106M19955.txt → s2-n1106m19955.txt
# ...
# Renamed: S2-N0108M19817.txt → s2-n0108m19817.txt
# Renamed: S2-N1106M27558.txt → s2-n1106m27558.txt
# Renamed: S2-N0108M08745.txt → s2-n0108m08745.txt
# Renamed: S2-N1106M09974.txt → s2-n1106m09974.txt
# Renamed: S2-N1106M00067.txt → s2-n1106m00067.txt
# Renamed: S2-O1301M03857.txt → s2-o1301m03857.txt
# Renamed: S2-N1105M00369.txt → s2-n1105m00369.txt
# Renamed: S2-N1105M06856.txt → s2-n1105m06856.txt
# Renamed: S2-N1104M03093.txt → s2-n1104m03093.txt
# Renamed: S2-N1105M02181.txt → s2-n1105m02181.txt
# Renamed: S2-N1104M02339.txt → s2-n1104m02339.txt
# Renamed: S2-N1106M17599.txt → s2-n1106m17599.txt
# Renamed: S2-N1206M23931.txt → s2-n1206m23931.txt
# Renamed: S2-N1105M09099.txt → s2-n1105m09099.txt
# Renamed: S2-N1105M02709.txt → s2-n1105m02709.txt
# Renamed: S2-N1106M02207.txt → s2-n1106m02207.txt
# Renamed: S2-N0108M05691.txt → s2-n0108m05691.txt
# Renamed: S2-N1105M05778.txt → s2-n1105m05778.txt
# Renamed: S2-N1106M06524.txt → s2-n1106m06524.txt
# Renamed: S2-N1105M01164.txt → s2-n1105m01164.txt
# Renamed: S2-N1105M06959.txt → s2-n1105m06959.txt
# Renamed: S2-O1301M04510.txt → s2-o1301m04510.txt
# Renamed: S2-N1206M01061.txt → s2-n1206m01061.txt
# Renamed: S2-N1106M02025.txt → s2-n1106m02025.txt
# Renamed: S2-N1106M28014.txt → s2-n1106m28014.txt
# Renamed: S2-N1001M01313.txt → s2-n1001m01313.txt
# Renamed: S2-N1106M07624.txt → s2-n1106m07624.txt
# Renamed: S2-N1106M00362.txt → s2-n1106m00362.txt
# Renamed: S2-N1001M02453.txt → s2-n1001m02453.txt
# Renamed: S2-N1105M08758.txt → s2-n1105m08758.txt
# Renamed: S2-N1105M25777.txt → s2-n1105m25777.txt
# Renamed: S2-N1001M03498.txt → s2-n1001m03498.txt
# Renamed: S2-N1106M03049.txt → s2-n1106m03049.txt
# Renamed: S2-N1104M00822.txt → s2-n1104m00822.txt
# Renamed: S2-N1106M19399.txt → s2-n1106m19399.txt
# Renamed: S2-N1105M09030.txt → s2-n1105m09030.txt
# Renamed: S2-N1105M05842.txt → s2-n1105m05842.txt
# Renamed: S2-N1105M17692.txt → s2-n1105m17692.txt
# Renamed: S2-N1106M20178.txt → s2-n1106m20178.txt
# Renamed: S2-N1106M03753.txt → s2-n1106m03753.txt
# Renamed: S2-N1206M04494.txt → s2-n1206m04494.txt
# Renamed: S2-N0110M08975.txt → s2-n0110m08975.txt
# Renamed: S2-N0110M08680.txt → s2-n0110m08680.txt
# Renamed: S2-N1106M26555.txt → s2-n1106m26555.txt
# Renamed: S2-N1105M00219.txt → s2-n1105m00219.txt
# Renamed: S2-N1105M04884.txt → s2-n1105m04884.txt
# Renamed: S2-N1106M11704.txt → s2-n1106m11704.txt
# Renamed: S2-N1106M29305.txt → s2-n1106m29305.txt
# Renamed: S2-N1106M24661.txt → s2-n1106m24661.txt
# Renamed: S2-O1301M00429.txt → s2-o1301m00429.txt
# Renamed: S2-N1001M00624.txt → s2-n1001m00624.txt
# Renamed: S2-N1106M01791.txt → s2-n1106m01791.txt
# Renamed: S2-N0109M08333.txt → s2-n0109m08333.txt
# Renamed: S2-N0109M34984.txt → s2-n0109m34984.txt
# Renamed: S2-N1105M01481.txt → s2-n1105m01481.txt
# Renamed: S2-N1106M17455.txt → s2-n1106m17455.txt
# Renamed: S2-N1001M05312.txt → s2-n1001m05312.txt
# Renamed: S2-N1106M17120.txt → s2-n1106m17120.txt
# Renamed: S2-N1106M13304.txt → s2-n1106m13304.txt
# Renamed: S2-N1106M05008.txt → s2-n1106m05008.txt
# Renamed: S2-N0109M30230.txt → s2-n0109m30230.txt
# Renamed: S2-N1402M10807.txt → s2-n1402m10807.txt
# Renamed: S2-O1301M01072.txt → s2-o1301m01072.txt
# Renamed: S2-N1106M21672.txt → s2-n1106m21672.txt
# Renamed: S2-N1106M16108.txt → s2-n1106m16108.txt
# Renamed: S2-N1105M09388.txt → s2-n1105m09388.txt
# Renamed: S2-N1105M16481.txt → s2-n1105m16481.txt
# Renamed: S2-N1106M22997.txt → s2-n1106m22997.txt
# Renamed: S2-N1402M04799.txt → s2-n1402m04799.txt
# Renamed: S2-N1106M01728.txt → s2-n1106m01728.txt
# Renamed: S2-N1106M13831.txt → s2-n1106m13831.txt
# Renamed: S2-N1105M00837.txt → s2-n1105m00837.txt
# Renamed: S2-N0109M37546.txt → s2-n0109m37546.txt
# Renamed: S2-N0109M37923.txt → s2-n0109m37923.txt
# Renamed: S2-N0108M20536.txt → s2-n0108m20536.txt
# Renamed: S2-N1104M00039.txt → s2-n1104m00039.txt
# Renamed: S2-N1106M03459.txt → s2-n1106m03459.txt
# Renamed: S2-O1301M01428.txt → s2-o1301m01428.txt
# Renamed: S2-N1106M25056.txt → s2-n1106m25056.txt
# Renamed: S2-N1402M03353.txt → s2-n1402m03353.txt
# Renamed: S2-N1105M12347.txt → s2-n1105m12347.txt
# Renamed: S2-O1101M00786.txt → s2-o1101m00786.txt
# Renamed: S2-N0109M14994.txt → s2-n0109m14994.txt
# Renamed: S2-N1104M03115.txt → s2-n1104m03115.txt
# Renamed: S2-N1104M02014.txt → s2-n1104m02014.txt
# Renamed: S2-N1105M01542.txt → s2-n1105m01542.txt
# Renamed: S2-N0109M03099.txt → s2-n0109m03099.txt
# Renamed: S2-N1106M09921.txt → s2-n1106m09921.txt
# Renamed: S2-N1206M21904.txt → s2-n1206m21904.txt
# Renamed: S2-N2104M25313.txt → s2-n2104m25313.txt
# Renamed: S2-N1106M09411.txt → s2-n1106m09411.txt
# Renamed: S2-N1106M02539.txt → s2-n1106m02539.txt
# Renamed: S2-N2103M22940.txt → s2-n2103m22940.txt
# Renamed: S2-N1105M09265.txt → s2-n1105m09265.txt
# Renamed: S2-N1206M20595.txt → s2-n1206m20595.txt
# Renamed: S2-N1106M19350.txt → s2-n1106m19350.txt
# Renamed: S2-N1104M02143.txt → s2-n1104m02143.txt
# Renamed: S2-N1106M15951.txt → s2-n1106m15951.txt
# Renamed: S2-O1102M00448.txt → s2-o1102m00448.txt
# Renamed: S2-N1106M10076.txt → s2-n1106m10076.txt
# Renamed: S2-N1105M07299.txt → s2-n1105m07299.txt
# Renamed: S2-N1106M21081.txt → s2-n1106m21081.txt
# Renamed: S2-N1104M00513.txt → s2-n1104m00513.txt
# Renamed: S2-N1402M12032.txt → s2-n1402m12032.txt
# Renamed: S2-N1106M11212.txt → s2-n1106m11212.txt
# Renamed: S2-N1106M18146.txt → s2-n1106m18146.txt
# Renamed: S2-O1103M06203.txt → s2-o1103m06203.txt
# Renamed: S2-N0109M41721.txt → s2-n0109m41721.txt
# Renamed: S2-N1206M23954.txt → s2-n1206m23954.txt
# Renamed: S2-O1301M01975.txt → s2-o1301m01975.txt
# Renamed: S2-N1106M21433.txt → s2-n1106m21433.txt
# Renamed: S2-N1106M16405.txt → s2-n1106m16405.txt
# Renamed: S2-N1106M23174.txt → s2-n1106m23174.txt
# Renamed: S2-N1105M26474.txt → s2-n1105m26474.txt
# Renamed: S2-N1106M04773.txt → s2-n1106m04773.txt
# Renamed: S2-N1106M11384.txt → s2-n1106m11384.txt
# Renamed: S2-N2104M26276.txt → s2-n2104m26276.txt
# Renamed: S2-N1401M04081.txt → s2-n1401m04081.txt
# Renamed: S2-N1106M04151.txt → s2-n1106m04151.txt
# Renamed: S2-N1106M29525.txt → s2-n1106m29525.txt
# Renamed: S2-N1106M15464.txt → s2-n1106m15464.txt
# Renamed: S2-N1105M01466.txt → s2-n1105m01466.txt
# Renamed: S2-N1402M02496.txt → s2-n1402m02496.txt
# Renamed: S2-N1206M06448.txt → s2-n1206m06448.txt
# Renamed: S2-N1105M12533.txt → s2-n1105m12533.txt
# Renamed: S2-N1105M05891.txt → s2-n1105m05891.txt
# Renamed: S2-N1105M10303.txt → s2-n1105m10303.txt
# Renamed: S2-N1106M08670.txt → s2-n1106m08670.txt
# Renamed: S2-N0109M03269.txt → s2-n0109m03269.txt
# Renamed: S2-N1105M03369.txt → s2-n1105m03369.txt
# Renamed: S2-N1106M19302.txt → s2-n1106m19302.txt
# Renamed: S2-N1106M26621.txt → s2-n1106m26621.txt
# Renamed: S2-N1104M01767.txt → s2-n1104m01767.txt
# Renamed: S2-N0109M35404.txt → s2-n0109m35404.txt
# Renamed: S2-N1106M19580.txt → s2-n1106m19580.txt
# Renamed: S2-N0109M50824.txt → s2-n0109m50824.txt
# Renamed: S2-N0110M00014.txt → s2-n0110m00014.txt
# Renamed: S2-N1106M19228.txt → s2-n1106m19228.txt
# Renamed: S2-N1105M05815.txt → s2-n1105m05815.txt
# Renamed: S2-N1106M08130.txt → s2-n1106m08130.txt
# Renamed: S2-N1105M10096.txt → s2-n1105m10096.txt
# Renamed: S2-N1105M08532.txt → s2-n1105m08532.txt
# Renamed: S2-N0109M38418.txt → s2-n0109m38418.txt
# Renamed: S2-N1106M08945.txt → s2-n1106m08945.txt
# Renamed: S2-N1401M01915.txt → s2-n1401m01915.txt
# Renamed: S2-N1106M23518.txt → s2-n1106m23518.txt
# Renamed: S2-N1105M02441.txt → s2-n1105m02441.txt
# Renamed: S2-N1106M05186.txt → s2-n1106m05186.txt
# Renamed: S2-N1106M05778.txt → s2-n1106m05778.txt
# Renamed: S2-N1105M08920.txt → s2-n1105m08920.txt
# Renamed: S2-N1105M07675.txt → s2-n1105m07675.txt
# Renamed: S2-N1106M03274.txt → s2-n1106m03274.txt
# Renamed: S2-N1206M08254.txt → s2-n1206m08254.txt
# Renamed: S2-N1106M11097.txt → s2-n1106m11097.txt
# Renamed: S2-N1106M17650.txt → s2-n1106m17650.txt
# Renamed: S2-N1106M08620.txt → s2-n1106m08620.txt
# Renamed: S2-N1104M00777.txt → s2-n1104m00777.txt
# Renamed: S2-N1106M18879.txt → s2-n1106m18879.txt
# Renamed: S2-N1106M04136.txt → s2-n1106m04136.txt
# Renamed: S2-N1105M26184.txt → s2-n1105m26184.txt
# Renamed: S2-N1106M11171.txt → s2-n1106m11171.txt
# Renamed: S2-N1105M02714.txt → s2-n1105m02714.txt
# Renamed: S2-O1302M00020.txt → s2-o1302m00020.txt
# Renamed: S2-N1106M10274.txt → s2-n1106m10274.txt
# Renamed: S2-O1103M00296.txt → s2-o1103m00296.txt
# Renamed: S2-N1106M07979.txt → s2-n1106m07979.txt
# Renamed: S2-N1106M19348.txt → s2-n1106m19348.txt
# Renamed: S2-N1106M14283.txt → s2-n1106m14283.txt
# Renamed: S2-N1402M04867.txt → s2-n1402m04867.txt
# Renamed: S2-N1106M08589.txt → s2-n1106m08589.txt
# Renamed: S2-N1105M22192.txt → s2-n1105m22192.txt
# Renamed: S2-N1106M03597.txt → s2-n1106m03597.txt
# Renamed: S2-N1106M28056.txt → s2-n1106m28056.txt
# Renamed: S2-N1106M12249.txt → s2-n1106m12249.txt
# Renamed: S2-N1105M08484.txt → s2-n1105m08484.txt
# Renamed: S2-N0109M00319.txt → s2-n0109m00319.txt
# Renamed: S2-N1106M01961.txt → s2-n1106m01961.txt
# Renamed: S2-N1105M06839.txt → s2-n1105m06839.txt
# Renamed: S2-N2104M18027.txt → s2-n2104m18027.txt
# Renamed: S2-N0108M18558.txt → s2-n0108m18558.txt
# Renamed: S2-O1301M03841.txt → s2-o1301m03841.txt
# Renamed: S2-N1402M01849.txt → s2-n1402m01849.txt
# Renamed: S2-N1106M12040.txt → s2-n1106m12040.txt
# Renamed: S2-N1106M18264.txt → s2-n1106m18264.txt
# Renamed: S2-N1106M02477.txt → s2-n1106m02477.txt
# Renamed: S2-N1106M12363.txt → s2-n1106m12363.txt
# Renamed: S2-N2104M19073.txt → s2-n2104m19073.txt
# Renamed: S2-O1301M02089.txt → s2-o1301m02089.txt
# Renamed: S2-N1106M16831.txt → s2-n1106m16831.txt
# Renamed: S2-N1104M02432.txt → s2-n1104m02432.txt
# Renamed: S2-N1106M00108.txt → s2-n1106m00108.txt
# Renamed: S2-N1105M07348.txt → s2-n1105m07348.txt
# Renamed: S2-N1105M05897.txt → s2-n1105m05897.txt
# Renamed: S2-N1106M06836.txt → s2-n1106m06836.txt
# Renamed: S2-N2104M19379.txt → s2-n2104m19379.txt
# Renamed: S2-N1106M29405.txt → s2-n1106m29405.txt
# Renamed: S2-N1106M19462.txt → s2-n1106m19462.txt
# Renamed: S2-N1106M16818.txt → s2-n1106m16818.txt
# Renamed: S2-N1106M26308.txt → s2-n1106m26308.txt
# Renamed: S2-N1106M17568.txt → s2-n1106m17568.txt
# Renamed: S2-N1106M17700.txt → s2-n1106m17700.txt
# Renamed: S2-N1106M14288.txt → s2-n1106m14288.txt
# Renamed: S2-N1106M15038.txt → s2-n1106m15038.txt
# Renamed: S2-N1106M16951.txt → s2-n1106m16951.txt
# Renamed: S2-N1106M07248.txt → s2-n1106m07248.txt
# Renamed: S2-N1106M18429.txt → s2-n1106m18429.txt
# Renamed: S2-N1106M22547.txt → s2-n1106m22547.txt
# Renamed: S2-N1402M10700.txt → s2-n1402m10700.txt
# Renamed: S2-N1106M15382.txt → s2-n1106m15382.txt
# Renamed: S2-N0109M07845.txt → s2-n0109m07845.txt
# Renamed: S2-N1106M04600.txt → s2-n1106m04600.txt
# Renamed: S2-N1105M09690.txt → s2-n1105m09690.txt
# Renamed: S2-N1106M06449.txt → s2-n1106m06449.txt
# Renamed: S2-N1106M02995.txt → s2-n1106m02995.txt
# Renamed: S2-N1001M00814.txt → s2-n1001m00814.txt
# Renamed: S2-N1105M04535.txt → s2-n1105m04535.txt
# Renamed: S2-N2104M12920.txt → s2-n2104m12920.txt
# Renamed: S2-N1106M02855.txt → s2-n1106m02855.txt
# Renamed: S2-N1106M24389.txt → s2-n1106m24389.txt
# Renamed: S2-N2104M26895.txt → s2-n2104m26895.txt
# Renamed: S2-N1105M01702.txt → s2-n1105m01702.txt
# Renamed: S2-N1106M05876.txt → s2-n1106m05876.txt
# Renamed: S2-N2104M13804.txt → s2-n2104m13804.txt
# Renamed: S2-N1106M02758.txt → s2-n1106m02758.txt
# Renamed: S2-N0109M15671.txt → s2-n0109m15671.txt
# Renamed: S2-N1106M11988.txt → s2-n1106m11988.txt
# Renamed: S2-N2104M26930.txt → s2-n2104m26930.txt
# Renamed: S2-N1106M18809.txt → s2-n1106m18809.txt
# Renamed: S2-N1106M01401.txt → s2-n1106m01401.txt
# Renamed: S2-N1105M21605.txt → s2-n1105m21605.txt
# Renamed: S2-N2104M13923.txt → s2-n2104m13923.txt
# Renamed: S2-N1401M01521.txt → s2-n1401m01521.txt
# Renamed: S2-N0109M41195.txt → s2-n0109m41195.txt
# Renamed: S2-N1106M20730.txt → s2-n1106m20730.txt
# Renamed: S2-N1105M09966.txt → s2-n1105m09966.txt
# Renamed: S2-N0109M02946.txt → s2-n0109m02946.txt
# Renamed: S2-N1105M08912.txt → s2-n1105m08912.txt
# Renamed: S2-N1106M03449.txt → s2-n1106m03449.txt
# Renamed: S2-N1106M14910.txt → s2-n1106m14910.txt
# Renamed: S2-N1105M27268.txt → s2-n1105m27268.txt
# Renamed: S2-O1301M03864.txt → s2-o1301m03864.txt
# Renamed: S2-N1106M20408.txt → s2-n1106m20408.txt
# Renamed: S2-N1106M17328.txt → s2-n1106m17328.txt
# Renamed: S2-N1106M04501.txt → s2-n1106m04501.txt
# Renamed: S2-O1302M00328.txt → s2-o1302m00328.txt
# Renamed: S2-N1105M00997.txt → s2-n1105m00997.txt
# Renamed: S2-N1206M00020.txt → s2-n1206m00020.txt
# Renamed: S2-N2104M12808.txt → s2-n2104m12808.txt
# Renamed: S2-N1001M04514.txt → s2-n1001m04514.txt
# Renamed: S2-O1301M00478.txt → s2-o1301m00478.txt
# Renamed: S2-N1106M29071.txt → s2-n1106m29071.txt
# Renamed: S2-N1106M01334.txt → s2-n1106m01334.txt
# Renamed: S2-N1106M14240.txt → s2-n1106m14240.txt
# Renamed: S2-N1105M12130.txt → s2-n1105m12130.txt
# Renamed: S2-N1106M15698.txt → s2-n1106m15698.txt
# Renamed: S2-N1105M17677.txt → s2-n1105m17677.txt
# Renamed: S2-N1206M17839.txt → s2-n1206m17839.txt
# Renamed: S2-N1401M01244.txt → s2-n1401m01244.txt
# Renamed: S2-N1105M05059.txt → s2-n1105m05059.txt
# Renamed: S2-N1104M00996.txt → s2-n1104m00996.txt
# Renamed: S2-N0110M02978.txt → s2-n0110m02978.txt
# Renamed: S2-N1106M08886.txt → s2-n1106m08886.txt
# Renamed: S2-N1106M06669.txt → s2-n1106m06669.txt
# Renamed: S2-N1105M26512.txt → s2-n1105m26512.txt
# Renamed: S2-N1105M01534.txt → s2-n1105m01534.txt
# Renamed: S2-N1106M15067.txt → s2-n1106m15067.txt
# Renamed: S2-N1106M27759.txt → s2-n1106m27759.txt
# Renamed: S2-N1106M02286.txt → s2-n1106m02286.txt
# Renamed: S2-N1106M20820.txt → s2-n1106m20820.txt
# Renamed: S2-N1105M02300.txt → s2-n1105m02300.txt
# Renamed: S2-O1301M04221.txt → s2-o1301m04221.txt
# Renamed: S2-O1102M01936.txt → s2-o1102m01936.txt
# Renamed: S2-N1106M05438.txt → s2-n1106m05438.txt
# Renamed: S2-N1206M13292.txt → s2-n1206m13292.txt
# Renamed: S2-O1103M05606.txt → s2-o1103m05606.txt
# Renamed: S2-N1401M01348.txt → s2-n1401m01348.txt
# Renamed: S2-N1402M04278.txt → s2-n1402m04278.txt
# Renamed: S2-N1106M26464.txt → s2-n1106m26464.txt
# Renamed: S2-N1105M27229.txt → s2-n1105m27229.txt
# Renamed: S2-N0108M21857.txt → s2-n0108m21857.txt
# Renamed: S2-N1106M21707.txt → s2-n1106m21707.txt
# Renamed: S2-N1105M12838.txt → s2-n1105m12838.txt
# Renamed: S2-N1105M27063.txt → s2-n1105m27063.txt
# Renamed: S2-N0109M39156.txt → s2-n0109m39156.txt
# Renamed: S2-N1106M16678.txt → s2-n1106m16678.txt
# Renamed: S2-N1106M03711.txt → s2-n1106m03711.txt
# Renamed: S2-N1106M08912.txt → s2-n1106m08912.txt
# Renamed: S2-N0109M40135.txt → s2-n0109m40135.txt
# Renamed: S2-N0109M53714.txt → s2-n0109m53714.txt
# Renamed: S2-N1106M18743.txt → s2-n1106m18743.txt
# Renamed: S2-N1106M10445.txt → s2-n1106m10445.txt
# Renamed: S2-N0109M36528.txt → s2-n0109m36528.txt
# Renamed: S2-O1301M00817.txt → s2-o1301m00817.txt
# Renamed: S2-N1105M24130.txt → s2-n1105m24130.txt
# Renamed: S2-N1106M16354.txt → s2-n1106m16354.txt
# Renamed: S2-N1105M07072.txt → s2-n1105m07072.txt
# Renamed: S2-N1106M06399.txt → s2-n1106m06399.txt
# Renamed: S2-N1106M02255.txt → s2-n1106m02255.txt
# Renamed: S2-N0109M05330.txt → s2-n0109m05330.txt
# Renamed: S2-N1106M23733.txt → s2-n1106m23733.txt
# Renamed: S2-N1106M05570.txt → s2-n1106m05570.txt
# Renamed: S2-N0109M00471.txt → s2-n0109m00471.txt
# Renamed: S2-O1301M01608.txt → s2-o1301m01608.txt
# Renamed: S2-N1001M05307.txt → s2-n1001m05307.txt
# Renamed: S2-N1401M01250.txt → s2-n1401m01250.txt
# Renamed: S2-N0109M36939.txt → s2-n0109m36939.txt
# Renamed: S2-N1001M05098.txt → s2-n1001m05098.txt
# Renamed: S2-O1301M00320.txt → s2-o1301m00320.txt
# Renamed: S2-N1106M23558.txt → s2-n1106m23558.txt
# Renamed: S2-N1105M14456.txt → s2-n1105m14456.txt
# Renamed: S2-N1104M02088.txt → s2-n1104m02088.txt
# Renamed: S2-N1106M28918.txt → s2-n1106m28918.txt
# Renamed: S2-N1206M06076.txt → s2-n1206m06076.txt
# Renamed: S2-O1301M00588.txt → s2-o1301m00588.txt
# Renamed: S2-N1106M00333.txt → s2-n1106m00333.txt
# Renamed: S2-N1106M15849.txt → s2-n1106m15849.txt
# Renamed: S2-N1106M16621.txt → s2-n1106m16621.txt
# Renamed: S2-N1402M08772.txt → s2-n1402m08772.txt
# Renamed: S2-N1106M16717.txt → s2-n1106m16717.txt
# Renamed: S2-N1106M20213.txt → s2-n1106m20213.txt
# Renamed: S2-N1106M17358.txt → s2-n1106m17358.txt
# Renamed: S2-N1106M25380.txt → s2-n1106m25380.txt
# Renamed: S2-N1105M11737.txt → s2-n1105m11737.txt
# Renamed: S2-N1106M02076.txt → s2-n1106m02076.txt
# Renamed: S2-N1105M00597.txt → s2-n1105m00597.txt
# Renamed: S2-N1106M16952.txt → s2-n1106m16952.txt

# %%
from pathlib import Path
import os

# 이미지 디렉토리 경로 지정
train_images_dir = Path("/content/YOLO_safety/train/images")

def rename_to_lowercase(directory):
    for img_file in directory.glob("*.*"):
        lower_name = img_file.with_name(img_file.stem.lower() + img_file.suffix.lower())
        if img_file != lower_name:  # 이름이 다를 때만 실행
            os.rename(img_file, lower_name)
            print(f"Renamed: {img_file.name} → {lower_name.name}")

# 실행
print("📂 Train 이미지 파일명 수정:")
rename_to_lowercase(train_images_dir)
# Out:
# 📂 Train 이미지 파일명 수정:
# Renamed: S2-N1105M00015.jpg → s2-n1105m00015.jpg
# Renamed: S2-N1104M02215.jpg → s2-n1104m02215.jpg
# Renamed: S2-N1106M03219.jpg → s2-n1106m03219.jpg
# Renamed: S2-N1104M01733.jpg → s2-n1104m01733.jpg
# Renamed: S2-N1106M04211.jpg → s2-n1106m04211.jpg
# Renamed: S2-N1106M04103.jpg → s2-n1106m04103.jpg
# Renamed: S2-N1104M02640.jpg → s2-n1104m02640.jpg
# Renamed: S2-N1105M02558.jpg → s2-n1105m02558.jpg
# Renamed: S2-N1105M07449.jpg → s2-n1105m07449.jpg
# Renamed: S2-N1105M05590.jpg → s2-n1105m05590.jpg
# Renamed: S2-N1106M08647.jpg → s2-n1106m08647.jpg
# Renamed: S2-N1106M07205.jpg → s2-n1106m07205.jpg
# Renamed: S2-N1106M10194.jpg → s2-n1106m10194.jpg
# Renamed: S2-N1105M12347.jpg → s2-n1105m12347.jpg
# Renamed: S2-N1105M20793.jpg → s2-n1105m20793.jpg
# Renamed: S2-N1106M04045.jpg → s2-n1106m04045.jpg
# Renamed: S2-O1301M02942.jpg → s2-o1301m02942.jpg
# Renamed: S2-N1106M10219.jpg → s2-n1106m10219.jpg
# Renamed: S2-N1105M20837.jpg → s2-n1105m20837.jpg
# Renamed: S2-N1105M08080.jpg → s2-n1105m08080.jpg
# Renamed: S2-N1106M10205.jpg → s2-n1106m10205.jpg
# Renamed: S2-N1106M06791.jpg → s2-n1106m06791.jpg
# Renamed: S2-N1105M02618.jpg → s2-n1105m02618.jpg
# Renamed: S2-N1105M09855.jpg → s2-n1105m09855.jpg
# Renamed: S2-N1105M02609.jpg → s2-n1105m02609.jpg
# Renamed: S2-N1104M02704.jpg → s2-n1104m02704.jpg
# Renamed: S2-N1105M07130.jpg → s2-n1105m07130.jpg
# Renamed: S2-N1106M04042.jpg → s2-n1106m04042.jpg
# Renamed: S2-N1106M18874.jpg → s2-n1106m18874.jpg
# Renamed: S2-N1106M18157.jpg → s2-n1106m18157.jpg
# Renamed: S2-N1106M16196.jpg → s2-n1106m16196.jpg
# Renamed: S2-N1106M03176.jpg → s2-n1106m03176.jpg
# Renamed: S2-N1106M10190.jpg → s2-n1106m10190.jpg
# Renamed: S2-N1106M04053.jpg → s2-n1106m04053.jpg
# Renamed: S2-O1102M01298.jpg → s2-o1102m01298.jpg
# Renamed: S2-N1104M01800.jpg → s2-n1104m01800.jpg
# Renamed: S2-N1106M09494.jpg → s2-n1106m09494.jpg
# Renamed: S2-N1105M07454.jpg → s2-n1105m07454.jpg
# Renamed: S2-N1104M02050.jpg → s2-n1104m02050.jpg
# Renamed: S2-N1105M07450.jpg → s2-n1105m07450.jpg
# Renamed: S2-N1106M01585.jpg → s2-n1106m01585.jpg
# Renamed: S2-N1105M14772.jpg → s2-n1105m14772.jpg
# Renamed: S2-N1106M11181.jpg → s2-n1106m11181.jpg
# Renamed: S2-N1105M05591.jpg → s2-n1105m05591.jpg
# Renamed: S2-N1104M02183.jpg → s2-n1104m02183.jpg

# %%
from pathlib import Path

# 디렉토리 설정
train_image_dir = Path("/content/YOLO_safety/train/images")
val_image_dir = Path("/content/YOLO_safety/val/images")

train_label_dir = Path("/content/YOLO_safety/train/labels")
val_label_dir = Path("/content/YOLO_safety/val/labels")

def check_dataset(image_dir, label_dir, dataset_name="Dataset"):
    images = list(image_dir.glob("*.jpg")) + list(image_dir.glob("*.png"))
    labels = list(label_dir.glob("*.txt"))

    image_names = {img.stem for img in images}
    label_names = {lbl.stem for lbl in labels}

    # 매칭 검사
    no_label = image_names - label_names  # 라벨 없는 이미지
    no_image = label_names - image_names  # 이미지 없는 라벨

    print(f"\n📂 {dataset_name} 데이터셋 확인")
    print(f" - 이미지 수: {len(images)}개")
    print(f" - 라벨 수: {len(labels)}개")

    if no_label:
        print(f" ⚠️ 라벨 없는 이미지 {len(no_label)}개 예시: {list(no_label)[:3]}")
    else:
        print(" ✅ 모든 이미지에 라벨이 존재")

    if no_image:
        print(f" ⚠️ 이미지 없는 라벨 {len(no_image)}개 예시: {list(no_image)[:3]}")
    else:
        print(" ✅ 모든 라벨에 대응되는 이미지 존재")

# 학습 / 검증 데이터셋 확인
check_dataset(train_image_dir, train_label_dir, "학습 (Train)")
check_dataset(val_image_dir, val_label_dir, "검증 (Val)")

# 총합
train_count = len(list(train_label_dir.glob("*.txt")))
val_count = len(list(val_label_dir.glob("*.txt")))
print(f"\n📊 총 라벨 파일 개수: {train_count + val_count}개 (학습 {train_count}개 + 검증 {val_count}개)")
# Out:
# 📂 학습 (Train) 데이터셋 확인
#  - 이미지 수: 43284개
#  - 라벨 수: 43284개
#  ✅ 모든 이미지에 라벨이 존재
#  ✅ 모든 라벨에 대응되는 이미지 존재
#
# 📂 검증 (Val) 데이터셋 확인
#  - 이미지 수: 10820개
#  - 라벨 수: 10820개
#  ✅ 모든 이미지에 라벨이 존재
#  ✅ 모든 라벨에 대응되는 이미지 존재
#
# 📊 총 라벨 파일 개수: 54104개 (학습 43284개 + 검증 10820개)

# %%
from pathlib import Path
import os

# 디렉토리 설정
train_image_dir = Path("/content/YOLO_safety/train/images")
val_image_dir = Path("/content/YOLO_safety/val/images")

train_label_dir = Path("/content/YOLO_safety/train/labels")
val_label_dir = Path("/content/YOLO_safety/val/labels")

# JSON 경로 설정 (YOLO 라벨 json 폴더가 있다면)
train_json_dir = Path("/content/YOLO_safety/train/labels_json")
val_json_dir = Path("/content/YOLO_safety/val/labels_json")

def clean_unmatched(image_dir, label_dir, json_dir=None, dataset_name="Dataset"):
    images = list(image_dir.glob("*.jpg")) + list(image_dir.glob("*.png"))
    labels = list(label_dir.glob("*.txt"))

    image_names = {img.stem for img in images}
    label_names = {lbl.stem for lbl in labels}

    # 매칭 검사
    no_label = image_names - label_names  # 라벨 없는 이미지
    no_image = label_names - image_names  # 이미지 없는 라벨

    print(f"\n🧹 {dataset_name} 데이터셋 정리 시작")

    # 라벨 없는 이미지 삭제
    for stem in no_label:
        for ext in [".jpg", ".png"]:
            img_path = image_dir / f"{stem}{ext}"
            if img_path.exists():
                os.remove(img_path)
                print(f"🗑️ 이미지 삭제: {img_path}")

        if json_dir:  # JSON도 같이 삭제
            json_path = json_dir / f"{stem}.json"
            if json_path.exists():
                os.remove(json_path)
                print(f"🗑️ JSON 삭제: {json_path}")

    # 이미지 없는 라벨 삭제
    for stem in no_image:
        txt_path = label_dir / f"{stem}.txt"
        if txt_path.exists():
            os.remove(txt_path)
            print(f"🗑️ 라벨 삭제: {txt_path}")

        if json_dir:
            json_path = json_dir / f"{stem}.json"
            if json_path.exists():
                os.remove(json_path)
                print(f"🗑️ JSON 삭제: {json_path}")

    print(f"✅ {dataset_name} 정리 완료")

# 실행
clean_unmatched(train_image_dir, train_label_dir, train_json_dir, "학습 (Train)")
clean_unmatched(val_image_dir, val_label_dir, val_json_dir, "검증 (Val)")
# Out:
# 🧹 학습 (Train) 데이터셋 정리 시작
# 🗑️ 이미지 삭제: /content/YOLO_safety/train/images/S2-N1106M17502.jpg
# 🗑️ JSON 삭제: /content/YOLO_safety/train/labels_json/S2-N1106M17502.json
# 🗑️ 이미지 삭제: /content/YOLO_safety/train/images/S2-N1104M00873.jpg
# 🗑️ JSON 삭제: /content/YOLO_safety/train/labels_json/S2-N1104M00873.json
# 🗑️ 이미지 삭제: /content/YOLO_safety/train/images/S2-N1105M06600.jpg
# 🗑️ JSON 삭제: /content/YOLO_safety/train/labels_json/S2-N1105M06600.json
# 🗑️ 이미지 삭제: /content/YOLO_safety/train/images/S2-O1301M01609.jpg
# 🗑️ JSON 삭제: /content/YOLO_safety/train/labels_json/S2-O1301M01609.json
# 🗑️ 이미지 삭제: /content/YOLO_safety/train/images/S2-N1106M16468.jpg
# 🗑️ JSON 삭제: /content/YOLO_safety/train/labels_json/S2-N1106M16468.json
# 🗑️ 이미지 삭제: /content/YOLO_safety/train/images/S2-N1105M04862.jpg
# 🗑️ JSON 삭제: /content/YOLO_safety/train/labels_json/S2-N1105M04862.json
# 🗑️ 이미지 삭제: /content/YOLO_safety/train/images/S2-N1106M13767.jpg
# 🗑️ JSON 삭제: /content/YOLO_safety/train/labels_json/S2-N1106M13767.json
# 🗑️ 이미지 삭제: /content/YOLO_safety/train/images/S2-N1105M11295.jpg
# 🗑️ JSON 삭제: /content/YOLO_safety/train/labels_json/S2-N1105M11295.json
# 🗑️ 이미지 삭제: /content/YOLO_safety/train/images/S2-N1106M11524.jpg
# 🗑️ JSON 삭제: /content/YOLO_safety/train/labels_json/S2-N1106M11524.json
# 🗑️ 이미지 삭제: /content/YOLO_safety/train/images/S2-O1103M01247.jpg
# 🗑️ JSON 삭제: /content/YOLO_safety/train/labels_json/S2-O1103M01247.json
# 🗑️ 이미지 삭제: /content/YOLO_safety/train/images/S2-N1104M01433.jpg
# 🗑️ JSON 삭제: /content/YOLO_safety/train/labels_json/S2-N1104M01433.json
# 🗑️ 이미지 삭제: /content/YOLO_safety/train/images/S2-N1105M21002.jpg
# 🗑️ JSON 삭제: /content/YOLO_safety/train/labels_json/S2-N1105M21002.json
# 🗑️ 이미지 삭제: /content/YOLO_safety/train/images/S2-N1106M10188.jpg
# 🗑️ JSON 삭제: /content/YOLO_safety/train/labels_json/S2-N1106M10188.json
# 🗑️ 이미지 삭제: /content/YOLO_safety/train/images/S2-N1106M18157.jpg
# 🗑️ JSON 삭제: /content/YOLO_safety/train/labels_json/S2-N1106M18157.json
# 🗑️ 이미지 삭제: /content/YOLO_safety/train/images/S2-N1106M10125.jpg
# 🗑️ JSON 삭제: /content/YOLO_safety/train/labels_json/S2-N1106M10125.json
# 🗑️ 이미지 삭제: /content/YOLO_safety/train/images/S2-N1106M06779.jpg
# 🗑️ JSON 삭제: /content/YOLO_safety/train/labels_json/S2-N1106M06779.json
# 🗑️ 이미지 삭제: /content/YOLO_safety/train/images/S2-N1105M00008.jpg
# 🗑️ JSON 삭제: /content/YOLO_safety/train/labels_json/S2-N1105M00008.json
# 🗑️ 이미지 삭제: /content/YOLO_safety/train/images/S2-N1105M05685.jpg
# 🗑️ JSON 삭제: /content/YOLO_safety/train/labels_json/S2-N1105M05685.json
# 🗑️ 이미지 삭제: /content/YOLO_safety/train/images/S2-N1106M04211.jpg
# 🗑️ JSON 삭제: /content/YOLO_safety/train/labels_json/S2-N1106M04211.json
# 🗑️ 이미지 삭제: /content/YOLO_safety/train/images/S2-N1105M02609.jpg
# 🗑️ JSON 삭제: /content/YOLO_safety/train/labels_json/S2-N1105M02609.json
# 🗑️ 이미지 삭제: /content/YOLO_safety/train/images/S2-N1106M11692.jpg
# 🗑️ JSON 삭제: /content/YOLO_safety/train/labels_json/S2-N1106M11692.json
# 🗑️ 이미지 삭제: /content/YOLO_safety/train/images/S2-N1106M27077.jpg
# 🗑️ JSON 삭제: /content/YOLO_safety/train/labels_json/S2-N1106M27077.json
# 🗑️ 이미지 삭제: /content/YOLO_safety/train/images/S2-N1106M05898.jpg
# 🗑️ JSON 삭제: /content/YOLO_safety/train/labels_json/S2-N1106M05898.json
# 🗑️ 이미지 삭제: /content/YOLO_safety/train/images/S2-N1105M10682.jpg
# 🗑️ JSON 삭제: /content/YOLO_safety/train/labels_json/S2-N1105M10682.json
# 🗑️ 이미지 삭제: /content/YOLO_safety/train/images/S2-N1106M01585.jpg
# 🗑️ JSON 삭제: /content/YOLO_safety/train/labels_json/S2-N1106M01585.json
# 🗑️ 이미지 삭제: /content/YOLO_safety/train/images/S2-N1106M04398.jpg
# 🗑️ JSON 삭제: /content/YOLO_safety/train/labels_json/S2-N1106M04398.json
# 🗑️ 이미지 삭제: /content/YOLO_safety/train/images/S2-N1105M26434.jpg
# 🗑️ JSON 삭제: /content/YOLO_safety/train/labels_json/S2-N1105M26434.json
# 🗑️ 이미지 삭제: /content/YOLO_safety/train/images/S2-N1106M22822.jpg
# 🗑️ JSON 삭제: /content/YOLO_safety/train/labels_json/S2-N1106M22822.json
# 🗑️ 이미지 삭제: /content/YOLO_safety/train/images/S2-N1104M01801.jpg
# 🗑️ JSON 삭제: /content/YOLO_safety/train/labels_json/S2-N1104M01801.json
# 🗑️ 이미지 삭제: /content/YOLO_safety/train/images/S2-N1105M11274.jpg
# 🗑️ JSON 삭제: /content/YOLO_safety/train/labels_json/S2-N1105M11274.json
# 🗑️ 이미지 삭제: /content/YOLO_safety/train/images/S2-N1105M04229.jpg
# 🗑️ JSON 삭제: /content/YOLO_safety/train/labels_json/S2-N1105M04229.json
# 🗑️ 이미지 삭제: /content/YOLO_safety/train/images/S2-N1105M04628.jpg
# 🗑️ JSON 삭제: /content/YOLO_safety/train/labels_json/S2-N1105M04628.json
# 🗑️ 이미지 삭제: /content/YOLO_safety/train/images/S2-N1106M23722.jpg
# 🗑️ JSON 삭제: /content/YOLO_safety/train/labels_json/S2-N1106M23722.json
# 🗑️ 이미지 삭제: /content/YOLO_safety/train/images/S2-N1106M06624.jpg
# 🗑️ JSON 삭제: /content/YOLO_safety/train/labels_json/S2-N1106M06624.json
# 🗑️ 이미지 삭제: /content/YOLO_safety/train/images/S2-N1106M10176.jpg
# 🗑️ JSON 삭제: /content/YOLO_safety/train/labels_json/S2-N1106M10176.json
# 🗑️ 이미지 삭제: /content/YOLO_safety/train/images/S2-N1105M05003.jpg
# 🗑️ JSON 삭제: /content/YOLO_safety/train/labels_json/S2-N1105M05003.json
# 🗑️ 이미지 삭제: /content/YOLO_safety/train/images/S2-N1106M06550.jpg
# 🗑️ JSON 삭제: /content/YOLO_safety/train/labels_json/S2-N1106M06550.json
# 🗑️ 이미지 삭제: /content/YOLO_safety/train/images/S2-N1105M18059.jpg
# 🗑️ JSON 삭제: /content/YOLO_safety/train/labels_json/S2-N1105M18059.json
# 🗑️ 이미지 삭제: /content/YOLO_safety/train/images/S2-N1106M23714.jpg
# 🗑️ JSON 삭제: /content/YOLO_safety/train/labels_json/S2-N1106M23714.json
# 🗑️ 이미지 삭제: /content/YOLO_safety/train/images/S2-O1302M00416.jpg
# 🗑️ JSON 삭제: /content/YOLO_safety/train/labels_json/S2-O1302M00416.json
# 🗑️ 이미지 삭제: /content/YOLO_safety/train/images/S2-N1106M23265.jpg
# 🗑️ JSON 삭제: /content/YOLO_safety/train/labels_json/S2-N1106M23265.json
# 🗑️ 이미지 삭제: /content/YOLO_safety/train/images/S2-N1105M07453.jpg
# 🗑️ JSON 삭제: /content/YOLO_safety/train/labels_json/S2-N1105M07453.json
# 🗑️ 이미지 삭제: /content/YOLO_safety/train/images/S2-N1106M18174.jpg
# 🗑️ JSON 삭제: /content/YOLO_safety/train/labels_json/S2-N1106M18174.json
# 🗑️ 이미지 삭제: /content/YOLO_safety/train/images/S2-N1104M01440.jpg
# 🗑️ JSON 삭제: /content/YOLO_safety/train/labels_json/S2-N1104M01440.json
# 🗑️ 이미지 삭제: /content/YOLO_safety/train/images/S2-N1106M06293.jpg
# 🗑️ JSON 삭제: /content/YOLO_safety/train/labels_json/S2-N1106M06293.json
# 🗑️ 이미지 삭제: /content/YOLO_safety/train/images/S2-N1106M04260.jpg
# 🗑️ JSON 삭제: /content/YOLO_safety/train/labels_json/S2-N1106M04260.json
# 🗑️ 이미지 삭제: /content/YOLO_safety/train/images/S2-N1106M10189.jpg
# 🗑️ JSON 삭제: /content/YOLO_safety/train/labels_json/S2-N1106M10189.json
# 🗑️ 이미지 삭제: /content/YOLO_safety/train/images/S2-N1106M22821.jpg
# 🗑️ JSON 삭제: /content/YOLO_safety/train/labels_json/S2-N1106M22821.json
# 🗑️ 이미지 삭제: /content/YOLO_safety/train/images/S2-N1105M05587.jpg
# 🗑️ JSON 삭제: /content/YOLO_safety/train/labels_json/S2-N1105M05587.json
# 🗑️ 이미지 삭제: /content/YOLO_safety/train/images/S2-N1105M06700.jpg
# 🗑️ JSON 삭제: /content/YOLO_safety/train/labels_json/S2-N1105M06700.json
# 🗑️ 이미지 삭제: /content/YOLO_safety/train/images/S2-N1104M02287.jpg
# 🗑️ JSON 삭제: /content/YOLO_safety/train/labels_json/S2-N1104M02287.json
# 🗑️ 이미지 삭제: /content/YOLO_safety/train/images/S2-N1105M03527.jpg
# 🗑️ JSON 삭제: /content/YOLO_safety/train/labels_json/S2-N1105M03527.json
# 🗑️ 이미지 삭제: /content/YOLO_safety/train/images/S2-N1105M07145.jpg
# 🗑️ JSON 삭제: /content/YOLO_safety/train/labels_json/S2-N1105M07145.json
# 🗑️ 이미지 삭제: /content/YOLO_safety/train/images/S2-N1105M21585.jpg
# 🗑️ JSON 삭제: /content/YOLO_safety/train/labels_json/S2-N1105M21585.json
# 🗑️ 이미지 삭제: /content/YOLO_safety/train/images/S2-N1105M05815.jpg
# 🗑️ JSON 삭제: /content/YOLO_safety/train/labels_json/S2-N1105M05815.json
# 🗑️ 이미지 삭제: /content/YOLO_safety/train/images/S2-N1105M04643.jpg
# 🗑️ JSON 삭제: /content/YOLO_safety/train/labels_json/S2-N1105M04643.json
# 🗑️ 이미지 삭제: /content/YOLO_safety/train/images/S2-N1105M06974.jpg
# 🗑️ JSON 삭제: /content/YOLO_safety/train/labels_json/S2-N1105M06974.json
# 🗑️ 이미지 삭제: /content/YOLO_safety/train/images/S2-N1106M00486.jpg
# 🗑️ JSON 삭제: /content/YOLO_safety/train/labels_json/S2-N1106M00486.json
# 🗑️ 이미지 삭제: /content/YOLO_safety/train/images/S2-N1106M11017.jpg
# 🗑️ JSON 삭제: /content/YOLO_safety/train/labels_json/S2-N1106M11017.json
# 🗑️ 이미지 삭제: /content/YOLO_safety/train/images/S2-N1105M00021.jpg
# 🗑️ JSON 삭제: /content/YOLO_safety/train/labels_json/S2-N1105M00021.json
# 🗑️ 이미지 삭제: /content/YOLO_safety/train/images/S2-N1105M26342.jpg
# 🗑️ JSON 삭제: /content/YOLO_safety/train/labels_json/S2-N1105M26342.json
# 🗑️ 이미지 삭제: /content/YOLO_safety/train/images/S2-N1106M21484.jpg
# 🗑️ JSON 삭제: /content/YOLO_safety/train/labels_json/S2-N1106M21484.json
# 🗑️ 이미지 삭제: /content/YOLO_safety/train/images/S2-N1104M01897.jpg
# 🗑️ JSON 삭제: /content/YOLO_safety/train/labels_json/S2-N1104M01897.json
# 🗑️ 이미지 삭제: /content/YOLO_safety/train/images/S2-N1105M14945.jpg
# 🗑️ JSON 삭제: /content/YOLO_safety/train/labels_json/S2-N1105M14945.json
# 🗑️ 이미지 삭제: /content/YOLO_safety/train/images/S2-N1105M14774.jpg
# 🗑️ JSON 삭제: /content/YOLO_safety/train/labels_json/S2-N1105M14774.json
# 🗑️ 이미지 삭제: /content/YOLO_safety/train/images/S2-N1106M02468.jpg
# 🗑️ JSON 삭제: /content/YOLO_safety/train/labels_json/S2-N1106M02468.json
# 🗑️ 이미지 삭제: /content/YOLO_safety/train/images/S2-N1105M09439.jpg
# 🗑️ JSON 삭제: /content/YOLO_safety/train/labels_json/S2-N1105M09439.json
# 🗑️ 이미지 삭제: /content/YOLO_safety/train/images/S2-N1105M18273.jpg
# 🗑️ JSON 삭제: /content/YOLO_safety/train/labels_json/S2-N1105M18273.json
# 🗑️ 이미지 삭제: /content/YOLO_safety/train/images/S2-O1103M00147.jpg
# 🗑️ JSON 삭제: /content/YOLO_safety/train/labels_json/S2-O1103M00147.json
# 🗑️ 이미지 삭제: /content/YOLO_safety/train/images/S2-N1104M02188.jpg
# 🗑️ JSON 삭제: /content/YOLO_safety/train/labels_json/S2-N1104M02188.json
# 🗑️ 이미지 삭제: /content/YOLO_safety/train/images/S2-N1105M05810.jpg
# 🗑️ JSON 삭제: /content/YOLO_safety/train/labels_json/S2-N1105M05810.json
# 🗑️ 이미지 삭제: /content/YOLO_safety/train/images/S2-N1105M02554.jpg
# 🗑️ JSON 삭제: /content/YOLO_safety/train/labels_json/S2-N1105M02554.json
# 🗑️ 이미지 삭제: /content/YOLO_safety/train/images/S2-N1105M14868.jpg
# 🗑️ JSON 삭제: /content/YOLO_safety/train/labels_json/S2-N1105M14868.json
# 🗑️ 이미지 삭제: /content/YOLO_safety/train/images/S2-N1106M07258.jpg
# 🗑️ JSON 삭제: /content/YOLO_safety/train/labels_json/S2-N1106M07258.json
# 🗑️ 이미지 삭제: /content/YOLO_safety/train/images/S2-N1104M01388.jpg
# 🗑️ JSON 삭제: /content/YOLO_safety/train/labels_json/S2-N1104M01388.json
# 🗑️ 이미지 삭제: /content/YOLO_safety/train/images/S2-N1105M05588.jpg
# 🗑️ JSON 삭제: /content/YOLO_safety/train/labels_json/S2-N1105M05588.json
# 🗑️ 이미지 삭제: /content/YOLO_safety/train/images/S2-N1106M23406.jpg
# 🗑️ JSON 삭제: /content/YOLO_safety/train/labels_json/S2-N1106M23406.json
# 🗑️ 이미지 삭제: /content/YOLO_safety/train/images/S2-N1105M11270.jpg
# 🗑️ JSON 삭제: /content/YOLO_safety/train/labels_json/S2-N1105M11270.json
# 🗑️ 이미지 삭제: /content/YOLO_safety/train/images/S2-N1104M00578.jpg
# 🗑️ JSON 삭제: /content/YOLO_safety/train/labels_json/S2-N1104M00578.json
# 🗑️ 이미지 삭제: /content/YOLO_safety/train/images/S2-N1104M01127.jpg
# 🗑️ JSON 삭제: /content/YOLO_safety/train/labels_json/S2-N1104M01127.json
# 🗑️ 이미지 삭제: /content/YOLO_safety/train/images/S2-N1105M14947.jpg
# 🗑️ JSON 삭제: /content/YOLO_safety/train/labels_json/S2-N1105M
txt
# 🗑️ 라벨 삭제: /content/YOLO_safety/train/labels/s2-n1106m03176.txt
# 🗑️ 라벨 삭제: /content/YOLO_safety/train/labels/s2-n1106m04319.txt
# 🗑️ 라벨 삭제: /content/YOLO_safety/train/labels/s2-n1105m03505.txt
# 🗑️ 라벨 삭제: /content/YOLO_safety/train/labels/s2-n1105m08339.txt
# 🗑️ 라벨 삭제: /content/YOLO_safety/train/labels/s2-n1105m05003.txt
# 🗑️ 라벨 삭제: /content/YOLO_safety/train/labels/s2-n1104m02061.txt
# 🗑️ 라벨 삭제: /content/YOLO_safety/train/labels/s2-n1104m02746.txt
# 🗑️ 라벨 삭제: /content/YOLO_safety/train/labels/s2-n1106m01585.txt
# 🗑️ 라벨 삭제: /content/YOLO_safety/train/labels/s2-n1105m02778.txt
# 🗑️ 라벨 삭제: /content/YOLO_safety/train/labels/s2-n1105m03087.txt
# 🗑️ 라벨 삭제: /content/YOLO_safety/train/labels/s2-n1106m10194.txt
# 🗑️ 라벨 삭제: /content/YOLO_safety/train/labels/s2-n1105m03097.txt
# 🗑️ 라벨 삭제: /content/YOLO_safety/train/labels/s2-n1105m03526.txt
# 🗑️ 라벨 삭제: /content/YOLO_safety/train/labels/s2-n1104m01022.txt
# 🗑️ 라벨 삭제: /content/YOLO_safety/train/labels/s2-n1105m14843.txt
# 🗑️ 라벨 삭제: /content/YOLO_safety/train/labels/s2-n1106m22759.txt
# 🗑️ 라벨 삭제: /content/YOLO_safety/train/labels/s2-n1105m04177.txt
# 🗑️ 라벨 삭제: /content/YOLO_safety/train/labels/s2-n1105m02837.txt
# 🗑️ 라벨 삭제: /content/YOLO_safety/train/labels/s2-n1105m23194.txt
# 🗑️ 라벨 삭제: /content/YOLO_safety/train/labels/s2-n1104m01899.txt
# 🗑️ 라벨 삭제: /content/YOLO_safety/train/labels/s2-n1106m00488.txt
# 🗑️ 라벨 삭제: /content/YOLO_safety/train/labels/s2-n1105m02558.txt
# 🗑️ 라벨 삭제: /content/YOLO_safety/train/labels/s2-n1105m03521.txt
# 🗑️ 라벨 삭제: /content/YOLO_safety/train/labels/s2-n1105m12475.txt
# 🗑️ 라벨 삭제: /content/YOLO_safety/train/labels/s2-n1106m04026.txt
# 🗑️ 라벨 삭제: /content/YOLO_safety/train/labels/s2-n1106m05349.txt
# 🗑️ 라벨 삭제: /content/YOLO_safety/train/labels/s2-n1105m04823.txt
# 🗑️ 라벨 삭제: /content/YOLO_safety/train/labels/s2-n1105m12454.txt
# 🗑️ 라벨 삭제: /content/YOLO_safety/train/labels/s2-n1105m04229.txt
# 🗑️ 라벨 삭제: /content/YOLO_safety/train/labels/s2-n1106m06721.txt
# 🗑️ 라벨 삭제: /content/YOLO_safety/train/labels/s2-n1105m04641.txt
# 🗑️ 라벨 삭제: /content/YOLO_safety/train/labels/s2-n1105m04223.txt
# 🗑️ 라벨 삭제: /content/YOLO_safety/train/labels/s2-n1106m10282.txt
# 🗑️ 라벨 삭제: /content/YOLO_safety/train/labels/s2-n1105m04626.txt
# 🗑️ 라벨 삭제: /content/YOLO_safety/train/labels/s2-n1106m04768.txt
# 🗑️ 라벨 삭제: /content/YOLO_safety/train/labels/s2-n1105m02617.txt
# 🗑️ 라벨 삭제: /content/YOLO_safety/train/labels/s2-n1104m01882.txt
# 🗑️ 라벨 삭제: /content/YOLO_safety/train/labels/s2-n1105m04623.txt
# 🗑️ 라벨 삭제: /content/YOLO_safety/train/labels/s2-n1104m01801.txt
# 🗑️ 라벨 삭제: /content/YOLO_safety/train/labels/s2-n1105m06600.txt
# 🗑️ 라벨 삭제: /content/YOLO_safety/train/labels/s2-n1106m06294.txt
# 🗑️ 라벨 삭제: /content/YOLO_safety/train/labels/s2-n1104m01434.txt
# 🗑️ 라벨 삭제: /content/YOLO_safety/train/labels/s2-o1301m00405.txt
# 🗑️ 라벨 삭제: /content/YOLO_safety/train/labels/s2-n1104m00038.txt
# 🗑️ 라벨 삭제: /content/YOLO_safety/train/labels/s2-n1106m18177.txt
# 🗑️ 라벨 삭제: /content/YOLO_safety/train/labels/s2-n1106m02814.txt
# 🗑️ 라벨 삭제: /content/YOLO_safety/train/labels/s2-n1106m04397.txt
# 🗑️ 라벨 삭제: /content/YOLO_safety/train/labels/s2-n1106m04380.txt
# 🗑️ 라벨 삭제: /content/YOLO_safety/train/labels/s2-n1104m02086.txt
# 🗑️ 라벨 삭제: /content/YOLO_safety/train/labels/s2-n1105m04645.txt
# 🗑️ 라벨 삭제: /content/YOLO_safety/train/labels/s2-n1106m08025.txt
# 🗑️ 라벨 삭제: /content/YOLO_safety/train/labels/s2-n1105m02658.txt
# 🗑️ 라벨 삭제: /content/YOLO_safety/train/labels/s2-n1105m02740.txt
# 🗑️ 라벨 삭제: /content/YOLO_safety/train/labels/s2-n1106m06792.txt
# 🗑️ 라벨 삭제: /content/YOLO_safety/train/labels/s2-n1106m18145.txt
# 🗑️ 라벨 삭제: /content/YOLO_safety/train/labels/s2-n1104m00363.txt
# 🗑️ 라벨 삭제: /content/YOLO_safety/train/labels/s2-o1103m02374.txt
# 🗑️ 라벨 삭제: /content/YOLO_safety/train/labels/s2-n1106m29832.txt
# 🗑️ 라벨 삭제: /content/YOLO_safety/train/labels/s2-n1105m04643.txt
# 🗑️ 라벨 삭제: /content/YOLO_safety/train/labels/s2-n1104m01922.txt
# 🗑️ 라벨 삭제: /content/YOLO_safety/train/labels/s2-n1105m09884.txt
# 🗑️ 라벨 삭제: /content/YOLO_safety/train/labels/s2-n1106m22821.txt
# 🗑️ 라벨 삭제: /content/YOLO_safety/train/labels/s2-n1105m04389.txt
# 🗑️ 라벨 삭제: /content/YOLO_safety/train/labels/s2-n1105m07360.txt
# 🗑️ 라벨 삭제: /content/YOLO_safety/train/labels/s2-n1104m03071.txt
# 🗑️ 라벨 삭제: /content/YOLO_safety/train/labels/s2-n1104m01799.txt
# 🗑️ 라벨 삭제: /content/YOLO_safety/train/labels/s2-n1106m08157.txt
# 🗑️ 라벨 삭제: /content/YOLO_safety/train/labels/s2-n1104m01388.txt
# 🗑️ 라벨 삭제: /content/YOLO_safety/train/labels/s2-n1106m03171.txt
# 🗑️ 라벨 삭제: /content/YOLO_safety/train/labels/s2-n1106m03173.txt
# 🗑️ 라벨 삭제: /content/YOLO_safety/train/labels/s2-n1106m07282.txt
# 🗑️ 라벨 삭제: /content/YOLO_safety/train/labels/s2-n1104m01733.txt
# 🗑️ 라벨 삭제: /content/YOLO_safety/train/labels/s2-n1105m11704.txt
# 🗑️ 라벨 삭제: /content/YOLO_safety/train/labels/s2-n1105m12386.txt
# 🗑️ 라벨 삭제: /content/YOLO_safety/train/labels/s2-n1104m01460.txt
# 🗑️ 라벨 삭제: /content/YOLO_safety/train/labels/s2-n1106m07527.txt
# 🗑️ 라벨 삭제: /content/YOLO_safety/train/labels/s2-n1106m06555.txt
# 🗑️ 라벨 삭제: /content/YOLO_safety/train/labels/s2-n1106m18154.txt
# 🗑️ 라벨 삭제: /content/YOLO_safety/train/labels/s2-n1106m08642.txt
# 🗑️ 라벨 삭제: /content/YOLO_safety/train/labels/s2-n1106m06145.txt
# 🗑️ 라벨 삭제: /content/YOLO_safety/train/labels/s2-n1105m18181.txt
# 🗑️ 라벨 삭제: /content/YOLO_safety/train/labels/s2-n1105m14856.txt
# 🗑️ 라벨 삭제: /content/YOLO_safety/train/labels/s2-n1106m02098.txt
# 🗑️ 라벨 삭제: /content/YOLO_safety/train/labels/s2-n1106m04394.txt
# 🗑️ 라벨 삭제: /content/YOLO_safety/train/labels/s2-n1105m04861.txt
# 🗑️ 라벨 삭제: /content/YOLO_safety/train/labels/s2-n1104m02254.txt
# 🗑️ 라벨 삭제: /content/YOLO_safety/train/labels/s2-n1105m14773.txt
# 🗑️ 라벨 삭제: /content/YOLO_safety/train/labels/s2-n1105m08670.txt
# 🗑️ 라벨 삭제: /content/YOLO_safety/train/labels/s2-n1106m22818.txt
# 🗑️ 라벨 삭제: /content/YOLO_safety/train/labels/s2-n1106m04765.txt
# 🗑️ 라벨 삭제: /content/YOLO_safety/train/labels/s2-n1106m13767.txt
# 🗑️ 라벨 삭제: /content/YOLO_safety/train/labels/s2-n1106m16190.txt
# 🗑️ 라벨 삭제: /content/YOLO_safety/train/labels/s2-n1105m04642.txt
# 🗑️ 라벨 삭제: /content/YOLO_safety/train/labels/s2-n1104m01898.txt
# 🗑️ 라벨 삭제: /content/YOLO_safety/train/labels/s2-n1105m06088.txt
# 🗑️ 라벨 삭제: /content/YOLO_safety/train/labels/s2-n1104m01574.txt
# 🗑️ 라벨 삭제: /content/YOLO_safety/train/labels/s2-n1106m04370.txt
# 🗑️ 라벨 삭제: /content/YOLO_safety/train/labels/s2-n1106m04058.txt
# 🗑️ 라벨 삭제: /content/YOLO_safety/train/labels/s2-n1105m14945.txt
# 🗑️ 라벨 삭제: /content/YOLO_safety/train/labels/s2-n1105m18185.txt
# 🗑️ 라벨 삭제: /content/YOLO_safety/train/labels/s2-n1104m02461.txt
# 🗑️ 라벨 삭제: /content/YOLO_safety/train/labels/s2-n1105m14889.txt
# 🗑️ 라벨 삭제: /content/YOLO_safety/train/labels/s2-n1106m09691.txt
# 🗑️ 라벨 삭제: /content/YOLO_safety/train/labels/s2-n1104m01198.txt
# 🗑️ 라벨 삭제: /content/YOLO_safety/train/labels/s2-n1106m11638.txt
# 🗑️ 라벨 삭제: /content/YOLO_safety/train/labels/s2-n1106m08646.txt
# 🗑️ 라벨 삭제: /content/YOLO_safety/train/labels/s2-n1105m04196.txt
# 🗑️ 라벨 삭제: /content/YOLO_safety/train/labels/s2-o1101m01697.txt
# 🗑️ 라벨 삭제: /content/YOLO_safety/train/labels/s2-n1105m14858.txt
# 🗑️ 라벨 삭제: /content/YOLO_safety/train/labels/s2-n1106m01935.txt
# 🗑️ 라벨 삭제: /content/YOLO_safety/train/labels/s2-n1104m01432.txt
# 🗑️ 라벨 삭제: /content/YOLO_safety/train/labels/s2-n1105m04224.txt
# 🗑️ 라벨 삭제: /content/YOLO_safety/train/labels/s2-n1106m06835.txt
# 🗑️ 라벨 삭제: /content/YOLO_safety/train/labels/s2-n1105m20794.txt
# 🗑️ 라벨 삭제: /content/YOLO_safety/train/labels/s2-n1106m10856.txt
# 🗑️ 라벨 삭제: /content/YOLO_safety/train/labels/s2-n1106m05244.txt
# 🗑️ 라벨 삭제: /content/YOLO_safety/train/labels/s2-n1104m02634.txt
# 🗑️ 라벨 삭제: /content/YOLO_safety/train/labels/s2-n1106m10205.txt
# 🗑️ 라벨 삭제: /content/YOLO_safety/train/labels/s2-n1106m08714.txt
# 🗑️ 라벨 삭제: /content/YOLO_safety/train/labels/s2-n1105m09443.txt
# 🗑️ 라벨 삭제: /content/YOLO_safety/train/labels/s2-o1301m01386.txt
# 🗑️ 라벨 삭제: /content/YOLO_safety/train/labels/s2-n1105m05712.txt
# 🗑️ 라벨 삭제: /content/YOLO_safety/train/labels/s2-n1106m18874.txt
# 🗑️ 라벨 삭제: /content/YOLO_safety/train/labels/s2-n1105m04238.txt
# 🗑️ 라벨 삭제: /content/YOLO_safety/train/labels/s2-n1105m06695.txt
# 🗑️ 라벨 삭제: /content/YOLO_safety/train/labels/s2-n1106m10178.txt
# ✅ 학습 (Train) 정리 완료
#
# 🧹 검증 (Val) 데이터셋 정리 시작
# ✅ 검증 (Val) 정리 완료

# %%
import os
from collections import Counter

def count_yolo_classes(label_dir, class_names=None):
    """
    YOLO 라벨(.txt) 파일에서 클래스별 인스턴스 수를 카운트합니다.

    :param label_dir: 라벨 파일(.txt)들이 있는 디렉토리
    :param class_names: 클래스 이름 리스트 (있으면 이름과 함께 출력됨)
    """
    counter = Counter()

    for filename in os.listdir(label_dir):
        if filename.endswith(".txt"):
            with open(os.path.join(label_dir, filename), "r", encoding="utf-8") as f:
                for line in f:
                    class_id = line.strip().split()[0]  # 첫 번째 값이 class_id
                    counter[int(class_id)] += 1

    print("📊 클래스별 인스턴스 수:")
    for class_id, count in sorted(counter.items()):
        name = class_names[class_id] if class_names else f"class_{class_id}"
        print(f"  {name} ({class_id}): {count}개")

    return counter

label_dir = "/content/YOLO_safety/train/labels"  # 또는 val
class_names = ["safety_harness", "safety_helmet"]
count_yolo_classes(label_dir, class_names)
# Out:
# 📊 클래스별 인스턴스 수:
#   safety_harness (0): 50498개
#   safety_helmet (1): 73563개
# Counter({0: 50498, 1: 73563})

# %% [markdown]
# # 이미지 경로 평탄화

# %%
import shutil
from pathlib import Path

def flatten_image_dir_skip_duplicates(img_base_dir: Path):
    flat_img_dir = img_base_dir

    for subdir in img_base_dir.iterdir():
        if subdir.is_dir():
            for img_file in subdir.glob("*.jpg"):
                target_path = flat_img_dir / img_file.name

                if target_path.exists():
                    print(f"⚠️ 중복으로 건너뜀: {img_file.name}")
                    continue

                shutil.move(str(img_file), str(target_path))

    print(f"✅ 중복 건너뛰며 평탄화 완료: {img_base_dir}")

# 적용
flatten_image_dir_skip_duplicates(Path("/content/YOLO_safety/train/images"))
flatten_image_dir_skip_duplicates(Path("/content/YOLO_safety/val/images"))
# Out:
# ✅ 중복 건너뛰며 평탄화 완료: /content/YOLO_safety/train/images
# ✅ 중복 건너뛰며 평탄화 완료: /content/YOLO_safety/val/images

# %% [markdown]
# # 데이터 존재 확인

# %%
from pathlib import Path

# 이미지 디렉토리 존재 확인
print("✅ train images exists:", Path("/content/YOLO_safety/train/images").exists())
print("✅ val images exists:", Path("/content/YOLO_safety/val/images").exists())

# 라벨 디렉토리 + 파일 개수 확인
val_labels = list(Path("/content/YOLO_safety/val/labels").glob("*.txt"))
print(f"✅ val 라벨 수: {len(val_labels)}개")

# 비어있는 파일 확인
empty = [f for f in val_labels if f.stat().st_size == 0]
print(f"⚠️ 비어있는 라벨 파일 수: {len(empty)}개")
# Out:
# ✅ train images exists: True
# ✅ val images exists: True
# ✅ val 라벨 수: 10820개
# ⚠️ 비어있는 라벨 파일 수: 0개

# %%
# 잘못된 클래스 ID가 있는지 확인
bad_lines = 0
for f in val_labels:
    lines = f.read_text().splitlines()
    for line in lines:
        parts = line.strip().split()
        if not parts:
            continue
        try:
            class_id = int(parts[0])
            if class_id not in [0, 1, 2]:
                print(f"⚠️ 잘못된 클래스 ID: {class_id} in {f.name}")
                bad_lines += 1
        except:
            print(f"⚠️ 형식 오류 in {f.name}: {line}")
            bad_lines += 1

print(f"❗ 잘못된 라벨 줄 수: {bad_lines}")
# Out:
# ❗ 잘못된 라벨 줄 수: 0

# %%
# 라벨 파일 몇 개 출력해보기 (예: 처음 3개)
for f in val_labels[:3]:
    print(f"\n📄 파일명: {f.name}")
    print(f.read_text())
# Out:
# 📄 파일명: s2-n1402m04638.txt
# 0 0.516667 0.649074 0.035417 0.083333
# 1 0.514062 0.583333 0.021875 0.042593
#
# 📄 파일명: s2-o1301m03746.txt
# 1 0.249219 0.481944 0.112500 0.261111
# 0 0.237109 0.772222 0.207031 0.455556
#
# 📄 파일명: s2-n1106m11241.txt
# 1 0.739062 0.221296 0.096875 0.235185
# 1 0.623958 0.368981 0.060417 0.125000
# 0 0.649479 0.561111 0.105208 0.277778
# 0 0.768490 0.569444 0.245312 0.507407

# %%
val_img_dir = Path("/content/YOLO_safety/val/images")
val_images = [f.stem for f in val_img_dir.glob("*.jpg")]
val_labels = [f.stem for f in Path("/content/YOLO_safety/val/labels").glob("*.txt")]

no_label_images = set(val_images) - set(val_labels)

print(f"⚠️ 라벨이 없는 이미지 수: {len(no_label_images)}")
print(list(no_label_images)[:5])  # 일부 예시
# Out:
# ⚠️ 라벨이 없는 이미지 수: 0
# []

# %%
import os

# 존재 확인
print("val 이미지 디렉토리 있음:", os.path.exists("/content/YOLO_safety/val/images"))
print("val 라벨 디렉토리 있음:", os.path.exists("/content/YOLO_safety/val/labels"))
# Out:
# val 이미지 디렉토리 있음: True
# val 라벨 디렉토리 있음: True

# %% [markdown]
# # 데이터 증강

# %%
import sys
sys.path.append('/content/drive/MyDrive')
from augmentations import apply_custom_augmentations

# %%
# /content/augmentations.py
import cv2
import numpy as np
import random

def apply_custom_augmentations(im, hyp):
    # Grayscale
    if hyp.get('grayscale', 0) > 0 and random.random() < hyp['grayscale']:
        im = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)
        im = cv2.cvtColor(im, cv2.COLOR_GRAY2BGR)

    # Brightness
    if hyp.get('brightness', 0) > 0 and random.random() < hyp['brightness']:
        factor = 1.0 + np.random.uniform(-0.2, 0.2)
        im = np.clip(im * factor, 0, 255).astype(np.uint8)

    # Gamma correction
    if hyp.get('gamma', 0) > 0 and random.random() < hyp['gamma']:
        gamma = np.random.uniform(0.7, 1.5)
        inv_gamma = 1.0 / gamma
        table = np.array([((i / 255.0) ** inv_gamma) * 255
                          for i in np.arange(256)]).astype("uint8")
        im = cv2.LUT(im, table)

    # CLAHE
    if hyp.get('clahe', 0) > 0 and random.random() < hyp['clahe']:
        lab = cv2.cvtColor(im, cv2.COLOR_BGR2LAB)
        l, a, b = cv2.split(lab)
        clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8, 8))
        cl = clahe.apply(l)
        merged = cv2.merge((cl, a, b))
        im = cv2.cvtColor(merged, cv2.COLOR_LAB2BGR)

    # Blur
    if hyp.get('blur', 0) > 0 and random.random() < hyp['blur']:
        k = random.choice([3, 5])  # 3x3 or 5x5 kernel
        im = cv2.GaussianBlur(im, (k, k), 0)

    # Gaussian Noise
    if hyp.get('noise', 0) > 0 and random.random() < hyp['noise']:
        noise = np.random.normal(0, 25, im.shape).astype(np.int16)
        im = np.clip(im.astype(np.int16) + noise, 0, 255).astype(np.uint8)

    return im

# %%
hyp_text = """
# /content/YOLO_safety/hyp_cctv.yaml

# 증강 - 좌우/상하 반전
fliplr: 0.3
flipud: 0.0

# 증강 - Mosaic & Mixup
mosaic: 0.6

# 증강 - 색상 계열 (HSV)
hsv_h: 0.015
hsv_s: 0.7
hsv_v: 0.4

# 증강 - 기하학 왜곡
translate: 0.2
scale: 0.2
"""
with open("/content/YOLO_safety/hyp_cctv.yaml", "w") as f:
    f.write(hyp_text)

print("hyp_cctv.yaml 저장 완료")
# Out:
# hyp_cctv.yaml 저장 완료

# %% [markdown]
# # 학습

# %%
yaml_text = """
path: /content/YOLO_safety
train: train/images
val: val/images

names:
  0: safety_harness
  1: safety_helmet
"""

with open("/content/YOLO_safety/safety.yaml", "w") as f:
    f.write(yaml_text)

print("safety.yaml 저장 완료")
# Out:
# safety.yaml 저장 완료

# %% [markdown]
# ## 증강 적용 X

# %%
# from ultralytics import YOLO
# model = YOLO("yolov8n.pt")  # 또는 yolov8s.pt -> yolov8n.pt -> yolov8m.pt

# model.train(
#     data="/content/YOLO_safety/safety.yaml",            # 데이터셋 구성정보가 담긴 yaml
#     epochs=50,                                          # 전체 학습 반복 횟수
#     imgsz=640,                                          # 학습에 사용할 입력 이미지 크기
#     project="/content/drive/MyDrive/YOLO_safety/runs",  # 실험 결과 저장 경로
#     name="safetyGear_detect_exp1"                       # 실험명
# )

# %% [markdown]
# ## 증강 적용 O

# %%
import sys
sys.path.append('/content/drive/MyDrive')
from augmentations import apply_custom_augmentations

# %%
import yaml
# hyp.yaml을 딕셔너리로 로드
with open("/content/YOLO_safety/hyp_cctv.yaml", "r") as f:
    hyp_dict = yaml.safe_load(f)

# %%
from ultralytics import YOLO
import yaml, cv2, torch
from augmentations import apply_custom_augmentations

# 증강 하이퍼파라미터 (외부 증강용)
custom_hyp = {
    "grayscale": 0.05,
    "brightness": 0.1,
    "gamma": 0.05,
    "clahe": 0.05,
    "blur": 0.1,
    "noise": 0.1,
}

# YOLO 내부 증강 하이퍼파라미터 로드
with open("/content/YOLO_safety/hyp_cctv.yaml", "r") as f:
    yolo_hyp = yaml.safe_load(f)

# 모델 로드
model = YOLO("yolov8m.pt")

#  외부 증강 콜백 정의
def custom_callback(trainer):
    # train 단계에서만 적용
    if trainer.mode != "train":
        return

    images = trainer.batch[0]
    for i in range(len(images)):
        im = images[i].permute(1,2,0).cpu().numpy()
        im = cv2.cvtColor(im, cv2.COLOR_RGB2BGR)

        # 외부 증강 적용
        im = apply_custom_augmentations(im, custom_hyp)

        im = cv2.cvtColor(im, cv2.COLOR_BGR2RGB)
        images[i] = torch.from_numpy(im).permute(2,0,1)

# 콜백 등록
model.add_callback("on_batch_start", custom_callback)

# 모델 학습
model.train(
    data="/content/YOLO_safety/safety.yaml",
    epochs=50,
    imgsz=960,
    project="/content/drive/MyDrive/YOLO_safety/runs",
    name="yolov8m_model_finished",
    optimizer="AdamW",
    cos_lr=True,
    patience=10,
    resume=False,
    save_period=5,
    **yolo_hyp  # YOLO 내부 증강
)
# Out:
# Ultralytics 8.3.170 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=True, cutmix=0.0, data=/content/YOLO_safety/safety.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=50, erasing=0.4, exist_ok=False, fliplr=0.3, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=960, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8m.pt, momentum=0.937, mosaic=0.6, multi_scale=False, name=yolov8m_model_finished2, nbs=64, nms=False, opset=None, optimize=False, optimizer=AdamW, overlap_mask=True, patience=10, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=/content/drive/MyDrive/YOLO_safety/runs, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/content/drive/MyDrive/YOLO_safety/runs/yolov8m_model_finished2, save_frames=False, save_json=False, save_period=5, save_txt=False, scale=0.2, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.2, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=2
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1392  ultralytics.nn.modules.conv.Conv             [3, 48, 3, 2]
#   1                  -1  1     41664  ultralytics.nn.modules.conv.Conv             [48, 96, 3, 2]
#   2                  -1  2    111360  ultralytics.nn.modules.block.C2f             [96, 96, 2, True]
#   3                  -1  1    166272  ultralytics.nn.modules.conv.Conv             [96, 192, 3, 2]
#   4                  -1  4    813312  ultralytics.nn.modules.block.C2f             [192, 192, 4, True]
#   5                  -1  1    664320  ultralytics.nn.modules.conv.Conv             [192, 384, 3, 2]
#   6                  -1  4   3248640  ultralytics.nn.modules.block.C2f             [384, 384, 4, True]
#   7                  -1  1   1991808  ultralytics.nn.modules.conv.Conv             [384, 576, 3, 2]
#   8                  -1  2   3985920  ultralytics.nn.modules.block.C2f             [576, 576, 2, True]
#   9                  -1  1    831168  ultralytics.nn.modules.block.SPPF            [576, 576, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  2   1993728  ultralytics.nn.modules.block.C2f             [960, 384, 2]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  2    517632  ultralytics.nn.modules.block.C2f             [576, 192, 2]
#  16                  -1  1    332160  ultralytics.nn.modules.conv.Conv             [192, 192, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  2   1846272  ultralytics.nn.modules.block.C2f             [576, 384, 2]
#  19                  -1  1   1327872  ultralytics.nn.modules.conv.Conv             [384, 384, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  2   4207104  ultralytics.nn.modules.block.C2f             [960, 576, 2]
#  22        [15, 18, 21]  1   3776854  ultralytics.nn.modules.head.Detect           [2, [192, 384, 576]]
# Model summary: 169 layers, 25,857,478 parameters, 25,857,462 gradients, 79.1 GFLOPs
#
# Transferred 469/475 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2261.8±1152.1 MB/s, size: 508.5 KB)
# train: Scanning /content/YOLO_safety/train/labels.cache... 43269 images, 0 backgrounds, 15 corrupt: 100%|██████████| 43284/43284 [00:00<?, ?it/s]
# train: /content/YOLO_safety/train/images/s2-n1104m01723.jpg: ignoring corrupt image/label: image file is truncated (7 bytes not processed)
# train: /content/YOLO_safety/train/images/s2-n1105m00865.jpg: ignoring corrupt image/label: image file is truncated (22 bytes not processed)
# train: /content/YOLO_safety/train/images/s2-n1105m18951.jpg: ignoring corrupt image/label: image file is truncated (72 bytes not processed)
# train: /content/YOLO_safety/train/images/s2-n1106m01094.jpg: ignoring corrupt image/label: image file is truncated (6 bytes not processed)
# train: /content/YOLO_safety/train/images/s2-n1106m02923.jpg: ignoring corrupt image/label: image file is truncated (3 bytes not processed)
# train: /content/YOLO_safety/train/images/s2-n1106m03577.jpg: ignoring corrupt image/label: cannot identify image file '/content/YOLO_safety/train/images/s2-n1106m03577.jpg'
# train: /content/YOLO_safety/train/images/s2-n1106m06353.jpg: ignoring corrupt image/label: image file is truncated (78 bytes not processed)
# train: /content/YOLO_safety/train/images/s2-n1106m07962.jpg: ignoring corrupt image/label: image file is truncated (6 bytes not processed)
# train: /content/YOLO_safety/train/images/s2-n1106m09627.jpg: ignoring corrupt image/label: image file is truncated (12 bytes not processed)
# train: /content/YOLO_safety/train/images/s2-n1106m11308.jpg: ignoring corrupt image/label: image file is truncated (76 bytes not processed)
# train: /content/YOLO_safety/train/images/s2-n1106m13036.jpg: ignoring corrupt image/label: image file is truncated (57 bytes not processed)
# train: /content/YOLO_safety/train/images/s2-n1106m15085.jpg: ignoring corrupt image/label: image file is truncated (14 bytes not processed)
# train: /content/YOLO_safety/train/images/s2-n1106m17452.jpg: ignoring corrupt image/label: image file is truncated (11 bytes not processed)
# train: /content/YOLO_safety/train/images/s2-n1106m19775.jpg: ignoring corrupt image/label: image file is truncated (31 bytes not processed)
# train: /content/YOLO_safety/train/images/s2-n1106m21736.jpg: ignoring corrupt image/label: image file is truncated (12 bytes not processed)
# train: /content/YOLO_safety/train/images/s2-o1301m03550.jpg: 1 duplicate labels removed
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1466.8±879.9 MB/s, size: 619.0 KB)
# val: Scanning /content/YOLO_safety/val/labels.cache... 10816 images, 0 backgrounds, 4 corrupt: 100%|██████████| 10820/10820 [00:00<?, ?it/s]
# val: /content/YOLO_safety/val/images/s2-n1105m02449.jpg: ignoring corrupt image/label: image file is truncated (65 bytes not processed)
# val: /content/YOLO_safety/val/images/s2-n1105m04217.jpg: ignoring corrupt image/label: image file is truncated (23 bytes not processed)
# val: /content/YOLO_safety/val/images/s2-n1105m26482.jpg: ignoring corrupt image/label: image file is truncated (78 bytes not processed)
# val: /content/YOLO_safety/val/images/s2-n1106m04618.jpg: ignoring corrupt image/label: image file is truncated (28 bytes not processed)
# Plotting labels to /content/drive/MyDrive/YOLO_safety/runs/yolov8m_model_finished2/labels.jpg...
# optimizer: AdamW(lr=0.01, momentum=0.937) with parameter groups 77 weight(decay=0.0), 84 weight(decay=0.0005), 83 bias(decay=0.0)
# Image sizes 960 train, 960 val
# Using 8 dataloader workers
# Logging results to /content/drive/MyDrive/YOLO_safety/runs/yolov8m_model_finished2
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/50      15.4G      1.398     0.9466        1.4         23        960: 100%|██████████| 2705/2705 [10:49<00:00,  4.16it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 338/338 [00:58<00:00,  5.75it/s]
#                    all      10816      30777       0.84      0.804       0.87      0.524
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/50      16.1G      1.323     0.7813       1.37         21        960: 100%|██████████| 2705/2705 [10:25<00:00,  4.33it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 338/338 [00:56<00:00,  5.96it/s]
#                    all      10816      30777       0.91      0.853       0.92      0.574
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/50      16.1G      1.282     0.7087      1.346         15        960: 100%|██████████| 2705/2705 [10:15<00:00,  4.39it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 338/338 [00:56<00:00,  5.96it/s]
#                    all      10816      30777      0.896      0.879      0.933      0.595
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/50      16.1G      1.249     0.6568      1.325         22        960: 100%|██████████| 2705/2705 [10:11<00:00,  4.42it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 338/338 [00:56<00:00,  6.01it/s]
#                    all      10816      30777       0.92      0.901      0.955      0.617
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/50      16.2G       1.22     0.6178      1.307         15        960: 100%|██████████| 2705/2705 [10:12<00:00,  4.42it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 338/338 [00:56<00:00,  6.03it/s]
#                    all      10816      30777      0.915       0.91      0.958      0.627
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/50      16.2G      1.207      0.595      1.299         10        960: 100%|██████████| 2705/2705 [10:12<00:00,  4.42it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 338/338 [00:56<00:00,  6.01it/s]
#                    all      10816      30777      0.933       0.92      0.966      0.638
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/50      16.2G      1.188     0.5766      1.288         23        960: 100%|██████████| 2705/2705 [10:12<00:00,  4.42it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 338/338 [00:57<00:00,  5.88it/s]
#                    all      10816      30777      0.933      0.924      0.968      0.645
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/50      16.2G      1.178     0.5649      1.285         24        960: 100%|██████████| 2705/2705 [10:12<00:00,  4.42it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 338/338 [00:56<00:00,  5.98it/s]
#                    all      10816      30777      0.936      0.928      0.971      0.651
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/50      16.2G      1.163     0.5456       1.27         31        960: 100%|██████████| 2705/2705 [10:12<00:00,  4.42it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 338/338 [00:56<00:00,  6.02it/s]
#                    all      10816      30777      0.938      0.936      0.973      0.657
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/50      16.2G      1.157     0.5356      1.265         30        960: 100%|██████████| 2705/2705 [10:12<00:00,  4.42it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 338/338 [00:56<00:00,  6.00it/s]
#                    all      10816      30777       0.94      0.938      0.975       0.66
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/50      16.2G      1.148     0.5261      1.259         11        960: 100%|██████████| 2705/2705 [10:12<00:00,  4.42it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 338/338 [00:56<00:00,  6.03it/s]
#                    all      10816      30777      0.941      0.939      0.976      0.665
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/50      16.2G      1.142     0.5173      1.251         24        960: 100%|██████████| 2705/2705 [10:12<00:00,  4.42it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 338/338 [00:56<00:00,  5.94it/s]
#                    all      10816      30777      0.944      0.939      0.976      0.667
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/50      16.2G      1.133     0.5097      1.246         20        960: 100%|██████████| 2705/2705 [10:12<00:00,  4.42it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 338/338 [00:56<00:00,  5.97it/s]
#                    all      10816      30777      0.943      0.942      0.977       0.67
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/50      16.2G      1.123     0.5011      1.244         70        960:  87%|████████▋ | 2358/2705 [08:54<01:21,  4.27it/s]

# %%
# from ultralytics import YOLO

# model = YOLO("/content/drive/MyDrive/YOLO_safety/runs/Yolov8m_model_1747/weights/last.pt")

# # 학습 실행
# model.train(
#     data="/content/YOLO_safety/safety.yaml",               # 데이터셋 구성 정보
#     epochs=50,                                             # 전체 epoch 수
#     imgsz=960,                                              # 입력 이미지 크기
#     project="/content/drive/MyDrive/YOLO_safety/runs",     # 결과 저장 경로
#     name="Yolov8m_model_many",                              # 실험 이름

#     # 성능 향상을 위한 사용자 지정 값
#     optimizer='AdamW',       # 더 나은 수렴 속도와 일반화
#     cos_lr=True,             # 부드러운 cosine 학습률 스케줄링
#     patience=20,             # EarlyStopping 인내심
#     seed=42,                 # 재현성 확보
#     save_period=5,          # 10 epoch마다 중간 모델 저장

#     **hyp_dict               # 사용자 정의 하이퍼파라미터 (flip, hsv 등)
# )
